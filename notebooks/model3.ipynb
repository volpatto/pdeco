# %% [markdown]
# # Aphid-Ladybeetle study

# %%
import copy
import numpy as np  # linear algebra
from numba import jit

import arviz as az
from arviz.utils import Numba
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp  # to solve ODE system
import pandas as pd
import pymc3 as pm  # for uncertainty quantification and model calibration
import theano  # to control better pymc3 backend and write a wrapper
import theano.tensor as t  # for the wrapper to a custom model to pymc3
import time
from tqdm.autonotebook import tqdm
import warnings
import sys

np.seterr('warn')
warnings.filterwarnings("ignore")
az.style.use("default")#,"arviz-colors")
#az.style.use("arviz-darkgrid")

Numba.enable_numba()

seed=1234
np.random.seed(seed)
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# /tmp/ipykernel_69447/3528856776.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## Obtaining Initial Conditions
#
# We need to define Initial Conditions as functions in order to define them for each discretization point. Here we will fit ICs as polynomial functions.

# %% [markdown]
# Loading data:

# %% [markdown]
# ### 2018_Lin_and_Pennings

# %%
data_dir = "../data/"
aphid_data = pd.read_csv(data_dir + 'aphid.CSV')
ladybeetle_data = pd.read_csv(data_dir + 'ladybeetle.CSV')

# %% [markdown]
# Retrieving IC data:

# %%
aphid_ic = aphid_data[aphid_data.Time == 1].Density.values[0]
ladybeetle_ic = ladybeetle_data[ladybeetle_data.Time == 1].Density.values[0]

aphid_density = aphid_data["Density"].values.flatten()
ladybeetle_density = ladybeetle_data["Density"].values.flatten()
time_list = aphid_data["Time"].values.flatten()

# %% [markdown]
# # Regularization

# %%
#%matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, ConstantKernel, ExpSineSquared

# %%
def read_data_file(path, filename):
    raw_data = pd.read_csv(f"{path}/{filename}", usecols=["Time", "Density"])
    return raw_data

# %%
def plot_data(time_list, density, mean_density, min_density, max_density):
    fig, ax = plt.subplots(figsize=(7, 4))
    
    ax.plot(time_list, density, 'o', c='b')
    ax.plot(t_list, mean_density, c='#000080')
    
    plt.xlabel('Time (days)')
    
    ax.set_ylim([0, 3233])
    plt.rc('axes', labelsize=20, titlesize=40),plt.xticks(fontsize=18),plt.yticks(fontsize=18)
#    plt.xticks(color='w'),plt.yticks(color='w')

    fig.set_tight_layout(True)

    ax.fill_between(t_list,
                    min_density,
                    max_density,
                    alpha=0.2,
                    color='blue')

# %%
t_list = time_list
t_list = np.linspace(t_list[0], t_list[-1], 200)
#t_list = np.linspace(-10, 50, 200)

def regularize_data(time_list, density):
    kernel = RBF(length_scale_bounds=(10,100)) + WhiteKernel(noise_level_bounds=(1e-10, 5e-10))

    model = GaussianProcessRegressor(kernel=kernel, alpha=1.0e-10, n_restarts_optimizer=50, normalize_y=np.max(density))
    model.fit(time_list.reshape(-1, 1), density)
    target_pred = model.predict(t_list.reshape(-1, 1), return_std=True)
    
    print(str(model.kernel_.get_params()))
    print("Initial: %s\nOptimum: %s\nLog-Marginal-Likelihood: %s"
          % (kernel, model.kernel_,
             model.log_marginal_likelihood(model.kernel_.theta)))
    
    mean_density = target_pred[0]
    err = 1.96 * np.max(density) * target_pred[1]
    min_density = target_pred[0] - err
    max_density = target_pred[0] + err
    
    return (mean_density, min_density, max_density)

# %%
fig, ax = plt.subplots(figsize=(1, 1))

ax.set_ylim([0, 3233])

ax.plot(time_list, aphid_data.Density.values, 'o', c='b')
ax.set(xlabel='Time (days)')
plt.rc('axes', labelsize=20, titlesize=40),plt.xticks(fontsize=18),plt.yticks(fontsize=18)
plt.ylabel('Aphid Abundance')
# Out:
# Text(0, 0.5, 'Aphid Abundance')

# %%
(mean_density, min_density, max_density) = regularize_data(time_list, aphid_density)
plot_data(time_list, aphid_density, mean_density, min_density, max_density)
plt.ylabel('Aphid Abundance')
plt.savefig("img/reg_aphid.png", dpi=300)
# Out:
# {'k1': RBF(length_scale=10), 'k2': WhiteKernel(noise_level=5e-10), 'k1__length_scale': 10.000000000000002, 'k1__length_scale_bounds': (10, 100), 'k2__noise_level': 5.000000000000012e-10, 'k2__noise_level_bounds': (1e-10, 5e-10)}
# Initial: RBF(length_scale=1) + WhiteKernel(noise_level=1)
# Optimum: RBF(length_scale=10) + WhiteKernel(noise_level=5e-10)
# Log-Marginal-Likelihood: -525176647.22261643

# %%
aphid_density = mean_density

# %%
t_list = time_list
t_list = np.linspace(t_list[0], t_list[-1], 200)

def regularize_data(time_list, density):
    kernel = ConstantKernel(constant_value_bounds = (1.0e-1, 1.0)) + WhiteKernel(noise_level_bounds = (1.0e-3, 1.0e-2))

    model = GaussianProcessRegressor(kernel=kernel, alpha=1.0e-10, n_restarts_optimizer=50, normalize_y=np.max(density))
    model.fit(time_list.reshape(-1, 1), density)
    target_pred = model.predict(t_list.reshape(-1, 1), return_std=True)
    
    print(str(model.kernel_.get_params()))
    print("Initial: %s\nOptimum: %s\nLog-Marginal-Likelihood: %s"
          % (kernel, model.kernel_,
             model.log_marginal_likelihood(model.kernel_.theta)))
    
    mean_density = target_pred[0]
    err = 1.96 * np.max(density) * target_pred[1]
    min_density = target_pred[0] - err
    max_density = target_pred[0] + err
    
    return (mean_density, min_density, max_density)

# %%
def plot_data(time_list, density, mean_density, min_density, max_density):
    fig, ax = plt.subplots(figsize=(7, 4))
    
    ax.plot(time_list, density, 'o', c='r')
    ax.plot(t_list, mean_density, c='#800000')
    
    plt.xlabel('Time (days)')
    
    ax.set_ylim([-0.2, 10])
    plt.rc('axes', labelsize=20, titlesize=40),plt.xticks(fontsize=18),plt.yticks(fontsize=18)
#    plt.xticks(color='w'),plt.yticks(color='w')

    fig.set_tight_layout(True)

    ax.fill_between(t_list,
                    min_density,
                    max_density,
                    alpha=0.2,
                    color='#FF6347')

# %%
(mean_density, min_density, max_density) = regularize_data(time_list, ladybeetle_density)
plot_data(time_list, ladybeetle_density, mean_density, min_density, max_density)
plt.ylabel('Ladybeetle Abundance')
plt.savefig("img/reg_ladybeetle.png", dpi=300)
# Out:
# {'k1': 0.316**2, 'k2': WhiteKernel(noise_level=0.01), 'k1__constant_value': 0.10000000000000006, 'k1__constant_value_bounds': (0.1, 1.0), 'k2__noise_level': 0.010000000000000005, 'k2__noise_level_bounds': (0.001, 0.01)}
# Initial: 1**2 + WhiteKernel(noise_level=1)
# Optimum: 0.316**2 + WhiteKernel(noise_level=0.01)
# Log-Marginal-Likelihood: -1655.8719413708159

# %%
ladybeetle_density = mean_density

# %%
aphid_ic = aphid_density[0]
ladybeetle_ic = ladybeetle_density[0]

# %%
y0 = aphid_ic, ladybeetle_ic

y0
# Out:
# (2400.511917153086, 4.147058823529371)

# %%
time_list = t_list

# %% [markdown]
# sys.exit(0)

# %% [markdown]
# # Model 3

# %%
import matplotlib.pyplot as plt
from numba import jit
import numpy as np  # linear algebra
from scipy.integrate import solve_ivp  # to solve ODE system
import pandas as pd

y0 = aphid_ic, ladybeetle_ic

@jit(nopython=True)
def M03_model(
    t,
    X,
    r1 = 10,
    ef = 0.15,
    m = 1.5,
    a1 = 1,
    a2 = 1,
):
    """
    Prey-Predator model (M03) python implementation.
    """
    u, v = X
    u_prime = r1 * u - a1 * u * u * v / ( 1 + a2 * u * u  )
    v_prime = ef * u * u * v / ( 1 + a2 * u * u ) - m * v * v
    return u_prime, v_prime

def M03_ode_solver(
    y0,
    t_span,
    t_eval,
    r1 = 10,
    ef = 0.15,
    m = 1.5,
    a1 = 1,
    a2 = 1,
):
    solution_ODE = solve_ivp(
        fun=M03_model,
        t_span=t_span,
        y0=y0,
        t_eval=t_eval,
        args=(r1,ef,m,a1,a2),
        method="Radau",
    )
    return solution_ODE

t0 = time_list.min()
tf = time_list.max()
days_to_forecast = 0
time_list_range = np.linspace(t0, tf + days_to_forecast, len(time_list))

u_data = aphid_density
v_data = ladybeetle_density

# %% [markdown]
# * We now need to calibrate the parameters of the function. Firstly, we have to define a least-squares residual error function:

# %%
def M03_least_squares_error_ode(
    par, time_list_exp, f_exp, fitting_model, initial_conditions
):
    args = par
    f_exp1, f_exp2 = f_exp
    time_list_span = (time_list_exp.min(), time_list_exp.max())

    weighting_for_exp1_constraints = 1
    weighting_for_exp2_constraints = 1
    num_of_qoi = len(f_exp)

    try:
        y_model = fitting_model(initial_conditions, time_list_span, time_list_exp, *args)
        simulated_time_list = y_model.t
        simulated_ode_solution = y_model.y
        simulated_qoi1, simulated_qoi2 = simulated_ode_solution

        residual1 = f_exp1 - simulated_qoi1
        residual2 = f_exp2 - simulated_qoi2

        first_term = weighting_for_exp1_constraints * np.sum(residual1 ** 2.0)
        second_term = weighting_for_exp2_constraints * np.sum(residual2 ** 2.0)

        objective_function = 1 / num_of_qoi * (first_term + second_term)
    except ValueError:
        objective_function = 1e15

    return objective_function

def callback_de(xk, convergence):
    """
    This function is to show the optimization procedure progress.
    """
    print(f'parameters = {xk}\n')

# %% [markdown]
# * Now we calibrate minimizing the residual applying the Differential Evolution method, a global optimization method, provided by `scipy`:

# %%
from scipy import optimize

seed=seed

r1=0.25
ef=1.6694019748331014e-06
m=0.0757563785190032
a1=0.0002007150113537963
a2=2.2769467819611236e-06
for i in range(1,10):
    r1_test=r1
    ef_test=ef
    m_test=m
    a1_test=a1
    a2_test=a2
    denom_min = 0.1
    denom_max = 1.9
    bounds_M03 = [
        ( ( r1_test ), ( r1_test ) ),  # r1
        ( ( ef_test * denom_min ), ( ef_test * denom_max ) ),  # ef
        ( ( m_test * denom_min ), ( m_test * denom_max ) ),  # m
        ( ( a1_test * denom_min ), ( a1_test * denom_max ) ),  # a1
        ( ( a2_test * denom_min ), ( a2_test * denom_max ) ),  # a2
    ]

    result_M03 = optimize.differential_evolution(
        M03_least_squares_error_ode,
        bounds=bounds_M03,
        args=(
            time_list,
            [aphid_density, ladybeetle_density],
            M03_ode_solver,
            y0,
        ),
        popsize=30,
        strategy="best1bin",
        tol=1e-5,
        recombination=0.95,
        mutation=0.6,
        maxiter=10000,
        polish=True,
        disp=True,
        seed=seed,
        callback=callback_de,
        workers=-1,
    )
    (
        r1,
        ef,
        m,
        a1,
        a2
    ) = result_M03.x
    print( "========================" + "\n" + "r1=" + str(r1) + "\n" + "ef=" + str(ef) + "\n" + "m=" + str(m) + "\n" + "a1=" + str(a1) + "\n" + "a2=" + str(a2) + "\n" + "========================" + "\n")
# Out:
# differential_evolution step 1: f(x)= 2.35107e+06
# parameters = [2.50000000e-01 1.94889324e-06 7.11426232e-02 2.03955253e-04
#  2.54574332e-06]
#
# differential_evolution step 2: f(x)= 2.35107e+06
# parameters = [2.50000000e-01 1.94889324e-06 7.11426232e-02 2.03955253e-04
#  2.54574332e-06]
#
# differential_evolution step 3: f(x)= 2.35107e+06
# parameters = [2.50000000e-01 1.94889324e-06 7.11426232e-02 2.03955253e-04
#  2.54574332e-06]
#
# differential_evolution step 4: f(x)= 2.35107e+06
# parameters = [2.50000000e-01 1.94889324e-06 7.11426232e-02 2.03955253e-04
#  2.54574332e-06]
#
# differential_evolution step 5: f(x)= 2.27019e+06
# parameters = [2.50000000e-01 1.83159912e-06 8.68945751e-02 2.54254686e-04
#  2.57486319e-06]
#
# differential_evolution step 6: f(x)= 2.27019e+06
# parameters = [2.50000000e-01 1.83159912e-06 8.68945751e-02 2.54254686e-04
#  2.57486319e-06]
#
# differential_evolution step 7: f(x)= 2.27019e+06
# parameters = [2.50000000e-01 1.83159912e-06 8.68945751e-02 2.54254686e-04
#  2.57486319e-06]
#
# differential_evolution step 8: f(x)= 2.27019e+06
# parameters = [2.50000000e-01 1.83159912e-06 8.68945751e-02 2.54254686e-04
#  2.57486319e-06]
#
# differential_evolution step 9: f(x)= 2.19882e+06
# parameters = [2.50000000e-01 1.90434657e-06 7.52306991e-02 2.42883932e-04
#  2.71433803e-06]
#
# differential_evolution step 10: f(x)= 2.19882e+06
# parameters = [2.50000000e-01 1.90434657e-06 7.52306991e-02 2.42883932e-04
#  2.71433803e-06]
#
# differential_evolution step 11: f(x)= 2.19882e+06
# parameters = [2.50000000e-01 1.90434657e-06 7.52306991e-02 2.42883932e-04
#  2.71433803e-06]
#
# differential_evolution step 12: f(x)= 1.94245e+06
# parameters = [2.50000000e-01 1.81198494e-06 8.17211848e-02 2.19513483e-04
#  2.41622829e-06]
#
# differential_evolution step 13: f(x)= 1.94245e+06
# parameters = [2.50000000e-01 1.81198494e-06 8.17211848e-02 2.19513483e-04
#  2.41622829e-06]
#
# differential_evolution step 14: f(x)= 1.93872e+06
# parameters = [2.50000000e-01 1.84945577e-06 8.24445444e-02 2.16563149e-04
#  2.41512689e-06]
#
# differential_evolution step 15: f(x)= 1.91508e+06
# parameters = [2.50000000e-01 1.74847024e-06 7.40648347e-02 1.97539009e-04
#  2.33115134e-06]
#
# differential_evolution step 16: f(x)= 1.90424e+06
# parameters = [2.50000000e-01 1.87234911e-06 8.13470352e-02 1.95691120e-04
#  2.30979292e-06]
#
# differential_evolution step 17: f(x)= 1.90424e+06
# parameters = [2.50000000e-01 1.87234911e-06 8.13470352e-02 1.95691120e-04
#  2.30979292e-06]
#
# differential_evolution step 18: f(x)= 1.88386e+06
# parameters = [2.50000000e-01 1.80321020e-06 7.80370777e-02 1.92989953e-04
#  2.28761815e-06]
#
# differential_evolution step 19: f(x)= 1.88386e+06
# parameters = [2.50000000e-01 1.80321020e-06 7.80370777e-02 1.92989953e-04
#  2.28761815e-06]
#
# differential_evolution step 20: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74358980e-06 7.68449778e-02 1.96587777e-04
#  2.28699564e-06]
#
# differential_evolution step 21: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74358980e-06 7.68449778e-02 1.96587777e-04
#  2.28699564e-06]
#
# differential_evolution step 22: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74358980e-06 7.68449778e-02 1.96587777e-04
#  2.28699564e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69431981e-06 7.63340449e-02 1.99810240e-04
#  2.28106712e-06]
#
# differential_evolution step 24: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67788151e-06 7.58063036e-02 2.01044489e-04
#  2.28414790e-06]
#
# differential_evolution step 25: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67788151e-06 7.58063036e-02 2.01044489e-04
#  2.28414790e-06]
#
# differential_evolution step 26: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68302204e-06 7.60892998e-02 2.01286660e-04
#  2.28576283e-06]
#
# differential_evolution step 27: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68302204e-06 7.60892998e-02 2.01286660e-04
#  2.28576283e-06]
#
# differential_evolution step 28: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.67242417e-06 7.59910928e-02 2.00264406e-04
#  2.27321093e-06]
#
# differential_evolution step 29: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.66714792e-06 7.56847636e-02 2.00354680e-04
#  2.27406220e-06]
#
# differential_evolution step 30: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67215165e-06 7.59214080e-02 2.00616490e-04
#  2.27617336e-06]
#
# differential_evolution step 31: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.66591897e-06 7.56578999e-02 2.00212605e-04
#  2.27260388e-06]
#
# differential_evolution step 32: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67671077e-06 7.59772922e-02 2.00681753e-04
#  2.27897617e-06]
#
# differential_evolution step 33: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.67122791e-06 7.57874400e-02 2.00756601e-04
#  2.27804507e-06]
#
# differential_evolution step 34: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66885058e-06 7.57723812e-02 2.00575402e-04
#  2.27549093e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66885058e-06 7.57723812e-02 2.00575402e-04
#  2.27549093e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66885058e-06 7.57723812e-02 2.00575402e-04
#  2.27549093e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66885058e-06 7.57723812e-02 2.00575402e-04
#  2.27549093e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846671e-06 7.57164054e-02 2.00585126e-04
#  2.27597541e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66813401e-06 7.57341443e-02 2.00571588e-04
#  2.27544227e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66826357e-06 7.57488809e-02 2.00572791e-04
#  2.27535094e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66974955e-06 7.57749784e-02 2.00694106e-04
#  2.27681634e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66974955e-06 7.57749784e-02 2.00694106e-04
#  2.27681634e-06]
#
# ========================
# r1=0.25
# ef=1.6697495471924951e-06
# m=0.07577497839730943
# a1=0.00020069410610257813
# a2=2.2768163383746996e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35189e+06
# parameters = [2.50000000e-01 1.94929900e-06 7.11600903e-02 2.03934010e-04
#  2.54559747e-06]
#
# differential_evolution step 2: f(x)= 2.35189e+06
# parameters = [2.50000000e-01 1.94929900e-06 7.11600903e-02 2.03934010e-04
#  2.54559747e-06]
#
# differential_evolution step 3: f(x)= 2.35189e+06
# parameters = [2.50000000e-01 1.94929900e-06 7.11600903e-02 2.03934010e-04
#  2.54559747e-06]
#
# differential_evolution step 4: f(x)= 2.35189e+06
# parameters = [2.50000000e-01 1.94929900e-06 7.11600903e-02 2.03934010e-04
#  2.54559747e-06]
#
# differential_evolution step 5: f(x)= 2.27099e+06
# parameters = [2.50000000e-01 1.83198046e-06 8.69159096e-02 2.54228205e-04
#  2.57471568e-06]
#
# differential_evolution step 6: f(x)= 2.27099e+06
# parameters = [2.50000000e-01 1.83198046e-06 8.69159096e-02 2.54228205e-04
#  2.57471568e-06]
#
# differential_evolution step 7: f(x)= 2.27099e+06
# parameters = [2.50000000e-01 1.83198046e-06 8.69159096e-02 2.54228205e-04
#  2.57471568e-06]
#
# differential_evolution step 8: f(x)= 2.27099e+06
# parameters = [2.50000000e-01 1.83198046e-06 8.69159096e-02 2.54228205e-04
#  2.57471568e-06]
#
# differential_evolution step 9: f(x)= 2.19806e+06
# parameters = [2.50000000e-01 1.90474305e-06 7.52491700e-02 2.42858635e-04
#  2.71418253e-06]
#
# differential_evolution step 10: f(x)= 2.19806e+06
# parameters = [2.50000000e-01 1.90474305e-06 7.52491700e-02 2.42858635e-04
#  2.71418253e-06]
#
# differential_evolution step 11: f(x)= 2.19806e+06
# parameters = [2.50000000e-01 1.90474305e-06 7.52491700e-02 2.42858635e-04
#  2.71418253e-06]
#
# differential_evolution step 12: f(x)= 1.94253e+06
# parameters = [2.50000000e-01 1.81236220e-06 8.17412492e-02 2.19490619e-04
#  2.41608987e-06]
#
# differential_evolution step 13: f(x)= 1.94253e+06
# parameters = [2.50000000e-01 1.81236220e-06 8.17412492e-02 2.19490619e-04
#  2.41608987e-06]
#
# differential_evolution step 14: f(x)= 1.93881e+06
# parameters = [2.50000000e-01 1.84984083e-06 8.24647864e-02 2.16540593e-04
#  2.41498853e-06]
#
# differential_evolution step 15: f(x)= 1.91505e+06
# parameters = [2.50000000e-01 1.74883428e-06 7.40830192e-02 1.97518434e-04
#  2.33101779e-06]
# differential_evolution step 16: f(x)= 1.90427e+06
# parameters = [2.50000000e-01 1.87273894e-06 8.13670077e-02 1.95670738e-04
#  2.30966060e-06]
#
# differential_evolution step 17: f(x)= 1.90427e+06
# parameters = [2.50000000e-01 1.87273894e-06 8.13670077e-02 1.95670738e-04
#  2.30966060e-06]
#
# differential_evolution step 18: f(x)= 1.88389e+06
# parameters = [2.50000000e-01 1.80358564e-06 7.80562376e-02 1.92969853e-04
#  2.28748710e-06]
#
# differential_evolution step 19: f(x)= 1.88389e+06
# parameters = [2.50000000e-01 1.80358564e-06 7.80562376e-02 1.92969853e-04
#  2.28748710e-06]
#
# differential_evolution step 20: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74395281e-06 7.68638449e-02 1.96567302e-04
#  2.28686462e-06]
#
# differential_evolution step 21: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74395281e-06 7.68638449e-02 1.96567302e-04
#  2.28686462e-06]
#
# differential_evolution step 22: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74395281e-06 7.68638449e-02 1.96567302e-04
#  2.28686462e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69467257e-06 7.63527867e-02 1.99789429e-04
#  2.28093644e-06]
#
# differential_evolution step 24: f(x)= 1.87841e+06
# parameters = [2.50000000e-01 1.67823084e-06 7.58249157e-02 2.01023549e-04
#  2.28401704e-06]
#
# differential_evolution step 25: f(x)= 1.87841e+06
# parameters = [2.50000000e-01 1.67823084e-06 7.58249157e-02 2.01023549e-04
#  2.28401704e-06]
#
# differential_evolution step 26: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68337245e-06 7.61079815e-02 2.01265695e-04
#  2.28563188e-06]
#
# differential_evolution step 27: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68337245e-06 7.61079815e-02 2.01265695e-04
#  2.28563188e-06]
#
# differential_evolution step 28: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.67277238e-06 7.60097503e-02 2.00243547e-04
#  2.27308071e-06]
#
# differential_evolution step 29: f(x)= 1.87821e+06
# parameters = [2.50000000e-01 1.66749502e-06 7.57033459e-02 2.00333813e-04
#  2.27393192e-06]
#
# differential_evolution step 30: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67249979e-06 7.59400484e-02 2.00595595e-04
#  2.27604296e-06]
#
# differential_evolution step 31: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.66626582e-06 7.56764756e-02 2.00191752e-04
#  2.27247368e-06]
#
# differential_evolution step 32: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67278880e-06 7.57751819e-02 2.00459462e-04
#  2.27742643e-06]
#
# differential_evolution step 33: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.66986744e-06 7.57177417e-02 2.00655136e-04
#  2.27734689e-06]
#
# differential_evolution step 34: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.66990050e-06 7.57256954e-02 2.00825447e-04
#  2.27836866e-06]
#
# differential_evolution step 35: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.66776018e-06 7.57082765e-02 2.00564204e-04
#  2.27547252e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67050071e-06 7.58247216e-02 2.00641315e-04
#  2.27637202e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67050071e-06 7.58247216e-02 2.00641315e-04
#  2.27637202e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67033783e-06 7.57759491e-02 2.00686899e-04
#  2.27716334e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66942907e-06 7.57598618e-02 2.00695694e-04
#  2.27680392e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66942907e-06 7.57598618e-02 2.00695694e-04
#  2.27680392e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66942907e-06 7.57598618e-02 2.00695694e-04
#  2.27680392e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66931026e-06 7.57512818e-02 2.00697424e-04
#  2.27683822e-06]
#
# differential_evolution step 43: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66931026e-06 7.57512818e-02 2.00697424e-04
#  2.27683822e-06]
#
# ========================
# r1=0.25
# ef=1.6693102597322559e-06
# m=0.07575128182618462
# a1=0.00020069742407439835
# a2=2.2768382224266394e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35093e+06
# parameters = [2.50000000e-01 1.94878617e-06 7.11378369e-02 2.03937382e-04
#  2.54562194e-06]
#
# differential_evolution step 2: f(x)= 2.35093e+06
# parameters = [2.50000000e-01 1.94878617e-06 7.11378369e-02 2.03937382e-04
#  2.54562194e-06]
#
# differential_evolution step 3: f(x)= 2.35093e+06
# parameters = [2.50000000e-01 1.94878617e-06 7.11378369e-02 2.03937382e-04
#  2.54562194e-06]
#
# differential_evolution step 4: f(x)= 2.35093e+06
# parameters = [2.50000000e-01 1.94878617e-06 7.11378369e-02 2.03937382e-04
#  2.54562194e-06]
#
# differential_evolution step 5: f(x)= 2.27013e+06
# parameters = [2.50000000e-01 1.83149849e-06 8.68887290e-02 2.54232408e-04
#  2.57474043e-06]
#
# differential_evolution step 6: f(x)= 2.27013e+06
# parameters = [2.50000000e-01 1.83149849e-06 8.68887290e-02 2.54232408e-04
#  2.57474043e-06]
#
# differential_evolution step 7: f(x)= 2.27013e+06
# parameters = [2.50000000e-01 1.83149849e-06 8.68887290e-02 2.54232408e-04
#  2.57474043e-06]
#
# differential_evolution step 8: f(x)= 2.27013e+06
# parameters = [2.50000000e-01 1.83149849e-06 8.68887290e-02 2.54232408e-04
#  2.57474043e-06]
#
# differential_evolution step 9: f(x)= 2.19891e+06
# parameters = [2.50000000e-01 1.90424194e-06 7.52256378e-02 2.42862650e-04
#  2.71420862e-06]
#
# differential_evolution step 10: f(x)= 2.19891e+06
# parameters = [2.50000000e-01 1.90424194e-06 7.52256378e-02 2.42862650e-04
#  2.71420862e-06]
#
# differential_evolution step 11: f(x)= 2.19891e+06
# parameters = [2.50000000e-01 1.90424194e-06 7.52256378e-02 2.42862650e-04
#  2.71420862e-06]
#
# differential_evolution step 12: f(x)= 1.94229e+06
# parameters = [2.50000000e-01 1.81188540e-06 8.17156868e-02 2.19494248e-04
#  2.41611309e-06]
#
# differential_evolution step 13: f(x)= 1.94229e+06
# parameters = [2.50000000e-01 1.81188540e-06 8.17156868e-02 2.19494248e-04
#  2.41611309e-06]
#
# differential_evolution step 14: f(x)= 1.93867e+06
# parameters = [2.50000000e-01 1.84935416e-06 8.24389978e-02 2.16544173e-04
#  2.41501174e-06]
#
# differential_evolution step 15: f(x)= 1.91506e+06
# parameters = [2.50000000e-01 1.74837419e-06 7.40598518e-02 1.97521700e-04
#  2.33104020e-06]
#
# differential_evolution step 16: f(x)= 1.90424e+06
# parameters = [2.50000000e-01 1.87224625e-06 8.13415624e-02 1.95673973e-04
#  2.30968280e-06]
#
# differential_evolution step 17: f(x)= 1.90424e+06
# parameters = [2.50000000e-01 1.87224625e-06 8.13415624e-02 1.95673973e-04
#  2.30968280e-06]
#
# differential_evolution step 18: f(x)= 1.88387e+06
# parameters = [2.50000000e-01 1.80311114e-06 7.80318276e-02 1.92973043e-04
#  2.28750908e-06]
#
# differential_evolution step 19: f(x)= 1.88387e+06
# parameters = [2.50000000e-01 1.80311114e-06 7.80318276e-02 1.92973043e-04
#  2.28750908e-06]
#
# differential_evolution step 20: f(x)= 1.88033e+06
# parameters = [2.50000000e-01 1.74349400e-06 7.68398079e-02 1.96570551e-04
#  2.28688660e-06]
#
# differential_evolution step 21: f(x)= 1.88033e+06
# parameters = [2.50000000e-01 1.74349400e-06 7.68398079e-02 1.96570551e-04
#  2.28688660e-06]
#
# differential_evolution step 22: f(x)= 1.88033e+06
# parameters = [2.50000000e-01 1.74349400e-06 7.68398079e-02 1.96570551e-04
#  2.28688660e-06]
#
# differential_evolution step 23: f(x)= 1.87871e+06
# parameters = [2.50000000e-01 1.69422672e-06 7.63289094e-02 1.99792732e-04
#  2.28095836e-06]
#
# differential_evolution step 24: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67778932e-06 7.58012036e-02 2.01026873e-04
#  2.28403900e-06]
#
# differential_evolution step 25: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67778932e-06 7.58012036e-02 2.01026873e-04
#  2.28403900e-06]
#
# differential_evolution step 26: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.68292958e-06 7.60841807e-02 2.01269022e-04
#  2.28565385e-06]
#
# differential_evolution step 27: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.68292958e-06 7.60841807e-02 2.01269022e-04
#  2.28565385e-06]
#
# differential_evolution step 28: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.67233229e-06 7.59859803e-02 2.00246858e-04
#  2.27310255e-06]
#
# differential_evolution step 29: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.66705632e-06 7.56796718e-02 2.00337125e-04
#  2.27395377e-06]
# differential_evolution step 30: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67205978e-06 7.59163002e-02 2.00598911e-04
#  2.27606484e-06]
#
# differential_evolution step 31: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67205978e-06 7.59163002e-02 2.00598911e-04
#  2.27606484e-06]
#
# differential_evolution step 32: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67205978e-06 7.59163002e-02 2.00598911e-04
#  2.27606484e-06]
#
# differential_evolution step 33: f(x)= 1.87815e+06
# parameters = [2.50000000e-01 1.66927459e-06 7.57480466e-02 2.00710846e-04
#  2.27697635e-06]
#
# differential_evolution step 34: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.67234399e-06 7.58019973e-02 2.00821825e-04
#  2.27905342e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66796322e-06 7.57249341e-02 2.00543804e-04
#  2.27525419e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66796322e-06 7.57249341e-02 2.00543804e-04
#  2.27525419e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67113424e-06 7.58300242e-02 2.00747307e-04
#  2.27742613e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67113424e-06 7.58300242e-02 2.00747307e-04
#  2.27742613e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67113424e-06 7.58300242e-02 2.00747307e-04
#  2.27742613e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66894026e-06 7.57711970e-02 2.00613660e-04
#  2.27580080e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66894026e-06 7.57711970e-02 2.00613660e-04
#  2.27580080e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66998477e-06 7.57843275e-02 2.00702423e-04
#  2.27691260e-06]
#
# differential_evolution step 43: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66998477e-06 7.57843275e-02 2.00702423e-04
#  2.27691260e-06]
#
# differential_evolution step 44: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970939e-06 7.57677141e-02 2.00705948e-04
#  2.27695817e-06]
#
# differential_evolution step 45: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970939e-06 7.57677141e-02 2.00705948e-04
#  2.27695817e-06]
#
# differential_evolution step 46: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970939e-06 7.57677141e-02 2.00705948e-04
#  2.27695817e-06]
#
# differential_evolution step 47: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66947827e-06 7.57649274e-02 2.00692516e-04
#  2.27674879e-06]
#
# ========================
# r1=0.25
# ef=1.669478271414205e-06
# m=0.0757649274264122
# a1=0.00020069251641185908
# a2=2.2767487929336583e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35131e+06
# parameters = [2.50000000e-01 1.94898231e-06 7.11506515e-02 2.03932395e-04
#  2.54552195e-06]
#
# differential_evolution step 2: f(x)= 2.35131e+06
# parameters = [2.50000000e-01 1.94898231e-06 7.11506515e-02 2.03932395e-04
#  2.54552195e-06]
#
# differential_evolution step 3: f(x)= 2.35131e+06
# parameters = [2.50000000e-01 1.94898231e-06 7.11506515e-02 2.03932395e-04
#  2.54552195e-06]
#
# differential_evolution step 4: f(x)= 2.35131e+06
# parameters = [2.50000000e-01 1.94898231e-06 7.11506515e-02 2.03932395e-04
#  2.54552195e-06]
#
# differential_evolution step 5: f(x)= 2.27056e+06
# parameters = [2.50000000e-01 1.83168283e-06 8.69043809e-02 2.54226191e-04
#  2.57463930e-06]
#
# differential_evolution step 6: f(x)= 2.27056e+06
# parameters = [2.50000000e-01 1.83168283e-06 8.69043809e-02 2.54226191e-04
#  2.57463930e-06]
#
# differential_evolution step 7: f(x)= 2.27056e+06
# parameters = [2.50000000e-01 1.83168283e-06 8.69043809e-02 2.54226191e-04
#  2.57463930e-06]
#
# differential_evolution step 8: f(x)= 2.27056e+06
# parameters = [2.50000000e-01 1.83168283e-06 8.69043809e-02 2.54226191e-04
#  2.57463930e-06]
#
# differential_evolution step 9: f(x)= 2.19828e+06
# parameters = [2.50000000e-01 1.90443360e-06 7.52391887e-02 2.42856711e-04
#  2.71410201e-06]
#
# differential_evolution step 10: f(x)= 2.19828e+06
# parameters = [2.50000000e-01 1.90443360e-06 7.52391887e-02 2.42856711e-04
#  2.71410201e-06]
#
# differential_evolution step 11: f(x)= 2.19828e+06
# parameters = [2.50000000e-01 1.90443360e-06 7.52391887e-02 2.42856711e-04
#  2.71410201e-06]
#
# differential_evolution step 12: f(x)= 1.94242e+06
# parameters = [2.50000000e-01 1.81206776e-06 8.17304068e-02 2.19488881e-04
#  2.41601819e-06]
#
# differential_evolution step 13: f(x)= 1.94242e+06
# parameters = [2.50000000e-01 1.81206776e-06 8.17304068e-02 2.19488881e-04
#  2.41601819e-06]
#
# differential_evolution step 14: f(x)= 1.93876e+06
# parameters = [2.50000000e-01 1.84954030e-06 8.24538481e-02 2.16538878e-04
#  2.41491688e-06]
#
# differential_evolution step 15: f(x)= 1.91501e+06
# parameters = [2.50000000e-01 1.74855015e-06 7.40731927e-02 1.97516870e-04
#  2.33094864e-06]
#
# differential_evolution step 16: f(x)= 1.9043e+06
# parameters = [2.50000000e-01 1.87243468e-06 8.13562150e-02 1.95669189e-04
#  2.30959208e-06]
#
# differential_evolution step 17: f(x)= 1.9043e+06
# parameters = [2.50000000e-01 1.87243468e-06 8.13562150e-02 1.95669189e-04
#  2.30959208e-06]
#
# differential_evolution step 18: f(x)= 1.88388e+06
# parameters = [2.50000000e-01 1.80329262e-06 7.80458840e-02 1.92968324e-04
#  2.28741924e-06]
#
# differential_evolution step 19: f(x)= 1.88388e+06
# parameters = [2.50000000e-01 1.80329262e-06 7.80458840e-02 1.92968324e-04
#  2.28741924e-06]
#
# differential_evolution step 20: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74366948e-06 7.68536495e-02 1.96565745e-04
#  2.28679677e-06]
#
# differential_evolution step 21: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74366948e-06 7.68536495e-02 1.96565745e-04
#  2.28679677e-06]
#
# differential_evolution step 22: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74366948e-06 7.68536495e-02 1.96565745e-04
#  2.28679677e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69439724e-06 7.63426590e-02 1.99787846e-04
#  2.28086877e-06]
#
# differential_evolution step 24: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67795819e-06 7.58148582e-02 2.01021957e-04
#  2.28394928e-06]
#
# differential_evolution step 25: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67795819e-06 7.58148582e-02 2.01021957e-04
#  2.28394928e-06]
#
# differential_evolution step 26: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.68309896e-06 7.60978863e-02 2.01264101e-04
#  2.28556408e-06]
#
# differential_evolution step 27: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.68309896e-06 7.60978863e-02 2.01264101e-04
#  2.28556408e-06]
#
# differential_evolution step 28: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.67250061e-06 7.59996682e-02 2.00241961e-04
#  2.27301327e-06]
#
# differential_evolution step 29: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.66722411e-06 7.56933045e-02 2.00332226e-04
#  2.27386446e-06]
#
# differential_evolution step 30: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67222807e-06 7.59299755e-02 2.00594006e-04
#  2.27597544e-06]
#
# differential_evolution step 31: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.66599511e-06 7.56664377e-02 2.00190167e-04
#  2.27240627e-06]
#
# differential_evolution step 32: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67678740e-06 7.59858661e-02 2.00659262e-04
#  2.27877800e-06]
#
# differential_evolution step 33: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.67130429e-06 7.57959924e-02 2.00734101e-04
#  2.27784698e-06]
#
# differential_evolution step 34: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.67130429e-06 7.57959924e-02 2.00734101e-04
#  2.27784698e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66954722e-06 7.57618292e-02 2.00624490e-04
#  2.27639735e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66954722e-06 7.57618292e-02 2.00624490e-04
#  2.27639735e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66954722e-06 7.57618292e-02 2.00624490e-04
#  2.27639735e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66954722e-06 7.57618292e-02 2.00624490e-04
#  2.27639735e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66927623e-06 7.57757337e-02 2.00633888e-04
#  2.27610650e-06]
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846278e-06 7.57431980e-02 2.00630015e-04
#  2.27592304e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846278e-06 7.57431980e-02 2.00630015e-04
#  2.27592304e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846278e-06 7.57431980e-02 2.00630015e-04
#  2.27592304e-06]
#
# differential_evolution step 43: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66879360e-06 7.57501637e-02 2.00654817e-04
#  2.27622178e-06]
#
# differential_evolution step 44: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66879360e-06 7.57501637e-02 2.00654817e-04
#  2.27622178e-06]
#
# differential_evolution step 45: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66879360e-06 7.57501637e-02 2.00654817e-04
#  2.27622178e-06]
#
# ========================
# r1=0.25
# ef=1.668793600117796e-06
# m=0.07575016372735514
# a1=0.00020065481678922917
# a2=2.2762217817108136e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35121e+06
# parameters = [2.50000000e-01 1.94818301e-06 7.11367869e-02 2.03894087e-04
#  2.54493273e-06]
#
# differential_evolution step 2: f(x)= 2.35121e+06
# parameters = [2.50000000e-01 1.94818301e-06 7.11367869e-02 2.03894087e-04
#  2.54493273e-06]
#
# differential_evolution step 3: f(x)= 2.35121e+06
# parameters = [2.50000000e-01 1.94818301e-06 7.11367869e-02 2.03894087e-04
#  2.54493273e-06]
#
# differential_evolution step 4: f(x)= 2.35121e+06
# parameters = [2.50000000e-01 1.94818301e-06 7.11367869e-02 2.03894087e-04
#  2.54493273e-06]
#
# differential_evolution step 5: f(x)= 2.2689e+06
# parameters = [2.50000000e-01 1.83093164e-06 8.68874466e-02 2.54178435e-04
#  2.57404333e-06]
#
# differential_evolution step 6: f(x)= 2.2689e+06
# parameters = [2.50000000e-01 1.83093164e-06 8.68874466e-02 2.54178435e-04
#  2.57404333e-06]
#
# differential_evolution step 7: f(x)= 2.2689e+06
# parameters = [2.50000000e-01 1.83093164e-06 8.68874466e-02 2.54178435e-04
#  2.57404333e-06]
#
# differential_evolution step 8: f(x)= 2.2689e+06
# parameters = [2.50000000e-01 1.83093164e-06 8.68874466e-02 2.54178435e-04
#  2.57404333e-06]
#
# differential_evolution step 9: f(x)= 2.19737e+06
# parameters = [2.50000000e-01 1.90365257e-06 7.52245275e-02 2.42811091e-04
#  2.71347376e-06]
#
# differential_evolution step 10: f(x)= 2.19737e+06
# parameters = [2.50000000e-01 1.90365257e-06 7.52245275e-02 2.42811091e-04
#  2.71347376e-06]
#
# differential_evolution step 11: f(x)= 2.19737e+06
# parameters = [2.50000000e-01 1.90365257e-06 7.52245275e-02 2.42811091e-04
#  2.71347376e-06]
#
# differential_evolution step 12: f(x)= 1.94239e+06
# parameters = [2.50000000e-01 1.81132461e-06 8.17144807e-02 2.19447650e-04
#  2.41545894e-06]
#
# differential_evolution step 13: f(x)= 1.94239e+06
# parameters = [2.50000000e-01 1.81132461e-06 8.17144807e-02 2.19447650e-04
#  2.41545894e-06]
#
# differential_evolution step 14: f(x)= 1.93834e+06
# parameters = [2.50000000e-01 1.84878178e-06 8.24377810e-02 2.16498201e-04
#  2.41435789e-06]
#
# differential_evolution step 15: f(x)= 1.915e+06
# parameters = [2.50000000e-01 1.74783306e-06 7.40587586e-02 1.97479767e-04
#  2.33040908e-06]
#
# differential_evolution step 16: f(x)= 1.90416e+06
# parameters = [2.50000000e-01 1.87166678e-06 8.13403618e-02 1.95632433e-04
#  2.30905746e-06]
#
# differential_evolution step 17: f(x)= 1.90416e+06
# parameters = [2.50000000e-01 1.87166678e-06 8.13403618e-02 1.95632433e-04
#  2.30905746e-06]
#
# differential_evolution step 18: f(x)= 1.88389e+06
# parameters = [2.50000000e-01 1.80255307e-06 7.80306758e-02 1.92932075e-04
#  2.28688975e-06]
#
# differential_evolution step 19: f(x)= 1.88389e+06
# parameters = [2.50000000e-01 1.80255307e-06 7.80306758e-02 1.92932075e-04
#  2.28688975e-06]
#
# differential_evolution step 20: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74295438e-06 7.68386737e-02 1.96528820e-04
#  2.28626744e-06]
#
# differential_evolution step 21: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74295438e-06 7.68386737e-02 1.96528820e-04
#  2.28626744e-06]
#
# differential_evolution step 22: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74295438e-06 7.68386737e-02 1.96528820e-04
#  2.28626744e-06]
#
# differential_evolution step 23: f(x)= 1.87869e+06
# parameters = [2.50000000e-01 1.69370235e-06 7.63277828e-02 1.99750317e-04
#  2.28034080e-06]
#
# differential_evolution step 24: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67727004e-06 7.58000847e-02 2.00984196e-04
#  2.28342061e-06]
#
# differential_evolution step 25: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67727004e-06 7.58000847e-02 2.00984196e-04
#  2.28342061e-06]
#
# differential_evolution step 26: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.68240871e-06 7.60830577e-02 2.01226294e-04
#  2.28503503e-06]
#
# differential_evolution step 27: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.68240871e-06 7.60830577e-02 2.01226294e-04
#  2.28503503e-06]
#
# differential_evolution step 28: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.68240871e-06 7.60830577e-02 2.01226294e-04
#  2.28503503e-06]
#
# differential_evolution step 29: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.66261243e-06 7.56077251e-02 1.99922682e-04
#  2.26910878e-06]
#
# differential_evolution step 30: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.66261243e-06 7.56077251e-02 1.99922682e-04
#  2.26910878e-06]
#
# differential_evolution step 31: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.66261243e-06 7.56077251e-02 1.99922682e-04
#  2.26910878e-06]
#
# differential_evolution step 32: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67340030e-06 7.59270913e-02 2.00391689e-04
#  2.27547904e-06]
#
# differential_evolution step 33: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67045753e-06 7.57904561e-02 2.00288185e-04
#  2.27454982e-06]
#
# differential_evolution step 34: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.66658933e-06 7.56875911e-02 2.00484998e-04
#  2.27441205e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67090506e-06 7.57991843e-02 2.00787061e-04
#  2.27789545e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67090506e-06 7.57991843e-02 2.00787061e-04
#  2.27789545e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67090506e-06 7.57991843e-02 2.00787061e-04
#  2.27789545e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66789274e-06 7.57262864e-02 2.00603493e-04
#  2.27558485e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66789274e-06 7.57262864e-02 2.00603493e-04
#  2.27558485e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970013e-06 7.57700252e-02 2.00713634e-04
#  2.27697121e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970013e-06 7.57700252e-02 2.00713634e-04
#  2.27697121e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970013e-06 7.57700252e-02 2.00713634e-04
#  2.27697121e-06]
#
# differential_evolution step 43: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66970013e-06 7.57700252e-02 2.00713634e-04
#  2.27697121e-06]
#
# ========================
# r1=0.25
# ef=1.6697001302317682e-06
# m=0.07577002515543245
# a1=0.00020071363412657258
# a2=2.2769712059993697e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35136e+06
# parameters = [2.50000000e-01 1.94924131e-06 7.11554387e-02 2.03953853e-04
#  2.54577062e-06]
#
# differential_evolution step 2: f(x)= 2.35136e+06
# parameters = [2.50000000e-01 1.94924131e-06 7.11554387e-02 2.03953853e-04
#  2.54577062e-06]
#
# differential_evolution step 3: f(x)= 2.35136e+06
# parameters = [2.50000000e-01 1.94924131e-06 7.11554387e-02 2.03953853e-04
#  2.54577062e-06]
#
# differential_evolution step 4: f(x)= 2.35136e+06
# parameters = [2.50000000e-01 1.94924131e-06 7.11554387e-02 2.03953853e-04
#  2.54577062e-06]
#
# differential_evolution step 5: f(x)= 2.27101e+06
# parameters = [2.50000000e-01 1.83192624e-06 8.69102281e-02 2.54252942e-04
#  2.57489081e-06]
#
# differential_evolution step 6: f(x)= 2.27101e+06
# parameters = [2.50000000e-01 1.83192624e-06 8.69102281e-02 2.54252942e-04
#  2.57489081e-06]
#
# differential_evolution step 7: f(x)= 2.27101e+06
# parameters = [2.50000000e-01 1.83192624e-06 8.69102281e-02 2.54252942e-04
#  2.57489081e-06]
#
# differential_evolution step 8: f(x)= 2.27101e+06
# parameters = [2.50000000e-01 1.83192624e-06 8.69102281e-02 2.54252942e-04
#  2.57489081e-06]
# differential_evolution step 9: f(x)= 2.19858e+06
# parameters = [2.50000000e-01 1.90468668e-06 7.52442511e-02 2.42882266e-04
#  2.71436715e-06]
#
# differential_evolution step 10: f(x)= 2.19858e+06
# parameters = [2.50000000e-01 1.90468668e-06 7.52442511e-02 2.42882266e-04
#  2.71436715e-06]
#
# differential_evolution step 11: f(x)= 2.19858e+06
# parameters = [2.50000000e-01 1.90468668e-06 7.52442511e-02 2.42882266e-04
#  2.71436715e-06]
#
# differential_evolution step 12: f(x)= 1.94249e+06
# parameters = [2.50000000e-01 1.81230856e-06 8.17359059e-02 2.19511976e-04
#  2.41625421e-06]
#
# differential_evolution step 13: f(x)= 1.94249e+06
# parameters = [2.50000000e-01 1.81230856e-06 8.17359059e-02 2.19511976e-04
#  2.41625421e-06]
#
# differential_evolution step 14: f(x)= 1.93889e+06
# parameters = [2.50000000e-01 1.84978608e-06 8.24593958e-02 2.16561663e-04
#  2.41515279e-06]
#
# differential_evolution step 15: f(x)= 1.91502e+06
# parameters = [2.50000000e-01 1.74878252e-06 7.40781766e-02 1.97537653e-04
#  2.33117635e-06]
#
# differential_evolution step 16: f(x)= 1.90433e+06
# parameters = [2.50000000e-01 1.87268351e-06 8.13616889e-02 1.95689778e-04
#  2.30981770e-06]
#
# differential_evolution step 17: f(x)= 1.90433e+06
# parameters = [2.50000000e-01 1.87268351e-06 8.13616889e-02 1.95689778e-04
#  2.30981770e-06]
#
# differential_evolution step 18: f(x)= 1.88387e+06
# parameters = [2.50000000e-01 1.80353226e-06 7.80511352e-02 1.92988629e-04
#  2.28764269e-06]
#
# differential_evolution step 19: f(x)= 1.88387e+06
# parameters = [2.50000000e-01 1.80353226e-06 7.80511352e-02 1.92988629e-04
#  2.28764269e-06]
#
# differential_evolution step 20: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74390120e-06 7.68588205e-02 1.96586428e-04
#  2.28702017e-06]
#
# differential_evolution step 21: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74390120e-06 7.68588205e-02 1.96586428e-04
#  2.28702017e-06]
#
# differential_evolution step 22: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74390120e-06 7.68588205e-02 1.96586428e-04
#  2.28702017e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69462241e-06 7.63477956e-02 1.99808869e-04
#  2.28109158e-06]
#
# differential_evolution step 24: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67818117e-06 7.58199592e-02 2.01043109e-04
#  2.28417240e-06]
#
# differential_evolution step 25: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67818117e-06 7.58199592e-02 2.01043109e-04
#  2.28417240e-06]
#
# differential_evolution step 26: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68332263e-06 7.61030064e-02 2.01285279e-04
#  2.28578735e-06]
#
# differential_evolution step 27: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68332263e-06 7.61030064e-02 2.01285279e-04
#  2.28578735e-06]
#
# differential_evolution step 28: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.67272287e-06 7.60047818e-02 2.00263031e-04
#  2.27323532e-06]
#
# differential_evolution step 29: f(x)= 1.87824e+06
# parameters = [2.50000000e-01 1.67272287e-06 7.60047818e-02 2.00263031e-04
#  2.27323532e-06]
#
# differential_evolution step 30: f(x)= 1.87822e+06
# parameters = [2.50000000e-01 1.65831295e-06 7.55422908e-02 2.01083695e-04
#  2.27434602e-06]
#
# differential_evolution step 31: f(x)= 1.87815e+06
# parameters = [2.50000000e-01 1.67476100e-06 7.58823480e-02 2.00510883e-04
#  2.27773279e-06]
#
# differential_evolution step 32: f(x)= 1.87815e+06
# parameters = [2.50000000e-01 1.67476100e-06 7.58823480e-02 2.00510883e-04
#  2.27773279e-06]
#
# differential_evolution step 33: f(x)= 1.87815e+06
# parameters = [2.50000000e-01 1.67476100e-06 7.58823480e-02 2.00510883e-04
#  2.27773279e-06]
#
# differential_evolution step 34: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.66825721e-06 7.57417994e-02 2.00333307e-04
#  2.27392083e-06]
#
# differential_evolution step 35: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.67263537e-06 7.58403500e-02 2.00821165e-04
#  2.27879587e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66795479e-06 7.57462676e-02 2.00566351e-04
#  2.27514259e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66943589e-06 7.57600681e-02 2.00633056e-04
#  2.27640134e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66943589e-06 7.57600681e-02 2.00633056e-04
#  2.27640134e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66943589e-06 7.57600681e-02 2.00633056e-04
#  2.27640134e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66943589e-06 7.57600681e-02 2.00633056e-04
#  2.27640134e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66893650e-06 7.57529064e-02 2.00616692e-04
#  2.27603879e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66981310e-06 7.57819088e-02 2.00694447e-04
#  2.27677527e-06]
#
# ========================
# r1=0.25
# ef=1.6698131025074583e-06
# m=0.07578190880969839
# a1=0.0002006944468100617
# a2=2.2767752666489173e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35186e+06
# parameters = [2.50000000e-01 1.94937320e-06 7.11665986e-02 2.03934356e-04
#  2.54555155e-06]
#
# differential_evolution step 2: f(x)= 2.35186e+06
# parameters = [2.50000000e-01 1.94937320e-06 7.11665986e-02 2.03934356e-04
#  2.54555155e-06]
#
# differential_evolution step 3: f(x)= 2.35186e+06
# parameters = [2.50000000e-01 1.94937320e-06 7.11665986e-02 2.03934356e-04
#  2.54555155e-06]
#
# differential_evolution step 4: f(x)= 2.35186e+06
# parameters = [2.50000000e-01 1.94937320e-06 7.11665986e-02 2.03934356e-04
#  2.54555155e-06]
#
# differential_evolution step 5: f(x)= 2.2713e+06
# parameters = [2.50000000e-01 1.83205019e-06 8.69238590e-02 2.54228636e-04
#  2.57466923e-06]
#
# differential_evolution step 6: f(x)= 2.2713e+06
# parameters = [2.50000000e-01 1.83205019e-06 8.69238590e-02 2.54228636e-04
#  2.57466923e-06]
#
# differential_evolution step 7: f(x)= 2.2713e+06
# parameters = [2.50000000e-01 1.83205019e-06 8.69238590e-02 2.54228636e-04
#  2.57466923e-06]
#
# differential_evolution step 8: f(x)= 2.2713e+06
# parameters = [2.50000000e-01 1.83205019e-06 8.69238590e-02 2.54228636e-04
#  2.57466923e-06]
#
# differential_evolution step 9: f(x)= 2.19782e+06
# parameters = [2.50000000e-01 1.90481555e-06 7.52560523e-02 2.42859047e-04
#  2.71413357e-06]
#
# differential_evolution step 10: f(x)= 2.19782e+06
# parameters = [2.50000000e-01 1.90481555e-06 7.52560523e-02 2.42859047e-04
#  2.71413357e-06]
#
# differential_evolution step 11: f(x)= 2.19782e+06
# parameters = [2.50000000e-01 1.90481555e-06 7.52560523e-02 2.42859047e-04
#  2.71413357e-06]
#
# differential_evolution step 12: f(x)= 1.94257e+06
# parameters = [2.50000000e-01 1.81243119e-06 8.17487253e-02 2.19490992e-04
#  2.41604629e-06]
#
# differential_evolution step 13: f(x)= 1.94257e+06
# parameters = [2.50000000e-01 1.81243119e-06 8.17487253e-02 2.19490992e-04
#  2.41604629e-06]
#
# differential_evolution step 14: f(x)= 1.93891e+06
# parameters = [2.50000000e-01 1.84991124e-06 8.24723287e-02 2.16540961e-04
#  2.41494496e-06]
#
# differential_evolution step 15: f(x)= 1.91498e+06
# parameters = [2.50000000e-01 1.74890084e-06 7.40897949e-02 1.97518770e-04
#  2.33097575e-06]
#
# differential_evolution step 16: f(x)= 1.90435e+06
# parameters = [2.50000000e-01 1.87281022e-06 8.13744496e-02 1.95671071e-04
#  2.30961893e-06]
#
# differential_evolution step 17: f(x)= 1.90435e+06
# parameters = [2.50000000e-01 1.87281022e-06 8.13744496e-02 1.95671071e-04
#  2.30961893e-06]
#
# differential_evolution step 18: f(x)= 1.8839e+06
# parameters = [2.50000000e-01 1.80365429e-06 7.80633766e-02 1.92970180e-04
#  2.28744583e-06]
#
# differential_evolution step 19: f(x)= 1.8839e+06
# parameters = [2.50000000e-01 1.80365429e-06 7.80633766e-02 1.92970180e-04
#  2.28744583e-06]
#
# differential_evolution step 20: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74401919e-06 7.68708749e-02 1.96567635e-04
#  2.28682336e-06]
#
# differential_evolution step 21: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74401919e-06 7.68708749e-02 1.96567635e-04
#  2.28682336e-06]
#
# differential_evolution step 22: f(x)= 1.8803e+06
# parameters = [2.50000000e-01 1.74401919e-06 7.68708749e-02 1.96567635e-04
#  2.28682336e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69473707e-06 7.63597699e-02 1.99789768e-04
#  2.28089529e-06]
# differential_evolution step 24: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67829472e-06 7.58318507e-02 2.01023891e-04
#  2.28397584e-06]
#
# differential_evolution step 25: f(x)= 1.8784e+06
# parameters = [2.50000000e-01 1.67829472e-06 7.58318507e-02 2.01023891e-04
#  2.28397584e-06]
#
# differential_evolution step 26: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68343653e-06 7.61149423e-02 2.01266037e-04
#  2.28559065e-06]
#
# differential_evolution step 27: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68343653e-06 7.61149423e-02 2.01266037e-04
#  2.28559065e-06]
#
# differential_evolution step 28: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68343653e-06 7.61149423e-02 2.01266037e-04
#  2.28559065e-06]
#
# differential_evolution step 29: f(x)= 1.87821e+06
# parameters = [2.50000000e-01 1.66362815e-06 7.56394105e-02 1.99962167e-04
#  2.26966053e-06]
#
# differential_evolution step 30: f(x)= 1.87821e+06
# parameters = [2.50000000e-01 1.66362815e-06 7.56394105e-02 1.99962167e-04
#  2.26966053e-06]
#
# differential_evolution step 31: f(x)= 1.87821e+06
# parameters = [2.50000000e-01 1.66362815e-06 7.56394105e-02 1.99962167e-04
#  2.26966053e-06]
#
# differential_evolution step 32: f(x)= 1.87818e+06
# parameters = [2.50000000e-01 1.67442261e-06 7.59589105e-02 2.00431267e-04
#  2.27603234e-06]
#
# differential_evolution step 33: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67147805e-06 7.58222181e-02 2.00327742e-04
#  2.27510290e-06]
#
# differential_evolution step 34: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66760749e-06 7.57193100e-02 2.00524594e-04
#  2.27496510e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67051064e-06 7.58035907e-02 2.00711298e-04
#  2.27710314e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67051064e-06 7.58035907e-02 2.00711298e-04
#  2.27710314e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66862319e-06 7.57349494e-02 2.00667507e-04
#  2.27638354e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66862319e-06 7.57349494e-02 2.00667507e-04
#  2.27638354e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66862319e-06 7.57349494e-02 2.00667507e-04
#  2.27638354e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66862319e-06 7.57349494e-02 2.00667507e-04
#  2.27638354e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66862319e-06 7.57349494e-02 2.00667507e-04
#  2.27638354e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66962343e-06 7.57714809e-02 2.00692565e-04
#  2.27676860e-06]
#
# ========================
# r1=0.25
# ef=1.669623432956235e-06
# m=0.07577148087433229
# a1=0.0002006925648051503
# a2=2.27676859840593e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.35118e+06
# parameters = [2.50000000e-01 1.94915177e-06 7.11568058e-02 2.03932444e-04
#  2.54554410e-06]
#
# differential_evolution step 2: f(x)= 2.35118e+06
# parameters = [2.50000000e-01 1.94915177e-06 7.11568058e-02 2.03932444e-04
#  2.54554410e-06]
#
# differential_evolution step 3: f(x)= 2.35118e+06
# parameters = [2.50000000e-01 1.94915177e-06 7.11568058e-02 2.03932444e-04
#  2.54554410e-06]
#
# differential_evolution step 4: f(x)= 2.35118e+06
# parameters = [2.50000000e-01 1.94915177e-06 7.11568058e-02 2.03932444e-04
#  2.54554410e-06]
#
# differential_evolution step 5: f(x)= 2.27118e+06
# parameters = [2.50000000e-01 1.83184210e-06 8.69118979e-02 2.54226252e-04
#  2.57466169e-06]
#
# differential_evolution step 6: f(x)= 2.27118e+06
# parameters = [2.50000000e-01 1.83184210e-06 8.69118979e-02 2.54226252e-04
#  2.57466169e-06]
#
# differential_evolution step 7: f(x)= 2.27118e+06
# parameters = [2.50000000e-01 1.83184210e-06 8.69118979e-02 2.54226252e-04
#  2.57466169e-06]
#
# differential_evolution step 8: f(x)= 2.27118e+06
# parameters = [2.50000000e-01 1.83184210e-06 8.69118979e-02 2.54226252e-04
#  2.57466169e-06]
#
# differential_evolution step 9: f(x)= 2.19832e+06
# parameters = [2.50000000e-01 1.90459919e-06 7.52456967e-02 2.42856770e-04
#  2.71412562e-06]
#
# differential_evolution step 10: f(x)= 2.19832e+06
# parameters = [2.50000000e-01 1.90459919e-06 7.52456967e-02 2.42856770e-04
#  2.71412562e-06]
#
# differential_evolution step 11: f(x)= 2.19832e+06
# parameters = [2.50000000e-01 1.90459919e-06 7.52456967e-02 2.42856770e-04
#  2.71412562e-06]
#
# differential_evolution step 12: f(x)= 1.94237e+06
# parameters = [2.50000000e-01 1.81222532e-06 8.17374763e-02 2.19488934e-04
#  2.41603921e-06]
#
# differential_evolution step 13: f(x)= 1.94237e+06
# parameters = [2.50000000e-01 1.81222532e-06 8.17374763e-02 2.19488934e-04
#  2.41603921e-06]
#
# differential_evolution step 14: f(x)= 1.93891e+06
# parameters = [2.50000000e-01 1.84970111e-06 8.24609801e-02 2.16538930e-04
#  2.41493789e-06]
#
# differential_evolution step 15: f(x)= 1.91493e+06
# parameters = [2.50000000e-01 1.74870219e-06 7.40795998e-02 1.97516917e-04
#  2.33096892e-06]
#
# differential_evolution step 16: f(x)= 1.90442e+06
# parameters = [2.50000000e-01 1.87259749e-06 8.13632521e-02 1.95669236e-04
#  2.30961217e-06]
#
# differential_evolution step 17: f(x)= 1.90442e+06
# parameters = [2.50000000e-01 1.87259749e-06 8.13632521e-02 1.95669236e-04
#  2.30961217e-06]
#
# differential_evolution step 18: f(x)= 1.88388e+06
# parameters = [2.50000000e-01 1.80344941e-06 7.80526348e-02 1.92968371e-04
#  2.28743913e-06]
#
# differential_evolution step 19: f(x)= 1.88388e+06
# parameters = [2.50000000e-01 1.80344941e-06 7.80526348e-02 1.92968371e-04
#  2.28743913e-06]
#
# differential_evolution step 20: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74382109e-06 7.68602972e-02 1.96565792e-04
#  2.28681667e-06]
#
# differential_evolution step 21: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74382109e-06 7.68602972e-02 1.96565792e-04
#  2.28681667e-06]
#
# differential_evolution step 22: f(x)= 1.88031e+06
# parameters = [2.50000000e-01 1.74382109e-06 7.68602972e-02 1.96565792e-04
#  2.28681667e-06]
#
# differential_evolution step 23: f(x)= 1.87871e+06
# parameters = [2.50000000e-01 1.69454457e-06 7.63492625e-02 1.99787895e-04
#  2.28088861e-06]
#
# differential_evolution step 24: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67810409e-06 7.58214159e-02 2.01022006e-04
#  2.28396915e-06]
#
# differential_evolution step 25: f(x)= 1.87839e+06
# parameters = [2.50000000e-01 1.67810409e-06 7.58214159e-02 2.01022006e-04
#  2.28396915e-06]
#
# differential_evolution step 26: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68324531e-06 7.61044686e-02 2.01264149e-04
#  2.28558396e-06]
#
# differential_evolution step 27: f(x)= 1.87826e+06
# parameters = [2.50000000e-01 1.68324531e-06 7.61044686e-02 2.01264149e-04
#  2.28558396e-06]
#
# differential_evolution step 28: f(x)= 1.87825e+06
# parameters = [2.50000000e-01 1.67264603e-06 7.60062420e-02 2.00242009e-04
#  2.27303304e-06]
#
# differential_evolution step 29: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.66736907e-06 7.56998517e-02 2.00332274e-04
#  2.27388424e-06]
#
# differential_evolution step 30: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67237347e-06 7.59365432e-02 2.00594054e-04
#  2.27599524e-06]
#
# differential_evolution step 31: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.66613997e-06 7.56729826e-02 2.00190215e-04
#  2.27242604e-06]
#
# differential_evolution step 32: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67693320e-06 7.59924386e-02 2.00659310e-04
#  2.27879783e-06]
#
# differential_evolution step 33: f(x)= 1.87814e+06
# parameters = [2.50000000e-01 1.67144961e-06 7.58025486e-02 2.00734150e-04
#  2.27786680e-06]
#
# differential_evolution step 34: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.67190536e-06 7.57860715e-02 2.00789887e-04
#  2.27877548e-06]
#
# differential_evolution step 35: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.67190536e-06 7.57860715e-02 2.00789887e-04
#  2.27877548e-06]
#
# differential_evolution step 36: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.67040237e-06 7.57705355e-02 2.00687609e-04
#  2.27729504e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66923184e-06 7.57655008e-02 2.00594147e-04
#  2.27595225e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67046615e-06 7.57915812e-02 2.00638956e-04
#  2.27674449e-06]
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846516e-06 7.57420111e-02 2.00630948e-04
#  2.27594918e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846516e-06 7.57420111e-02 2.00630948e-04
#  2.27594918e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846516e-06 7.57420111e-02 2.00630948e-04
#  2.27594918e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66846516e-06 7.57420111e-02 2.00630948e-04
#  2.27594918e-06]
#
# ========================
# r1=0.25
# ef=1.6684651555337694e-06
# m=0.07574201113489973
# a1=0.00020063094758723956
# a2=2.2759491780195893e-06
# ========================
#
# differential_evolution step 1: f(x)= 2.3508e+06
# parameters = [2.50000000e-01 1.94779958e-06 7.11291308e-02 2.03869832e-04
#  2.54462794e-06]
#
# differential_evolution step 2: f(x)= 2.3508e+06
# parameters = [2.50000000e-01 1.94779958e-06 7.11291308e-02 2.03869832e-04
#  2.54462794e-06]
#
# differential_evolution step 3: f(x)= 2.3508e+06
# parameters = [2.50000000e-01 1.94779958e-06 7.11291308e-02 2.03869832e-04
#  2.54462794e-06]
#
# differential_evolution step 4: f(x)= 2.3508e+06
# parameters = [2.50000000e-01 1.94779958e-06 7.11291308e-02 2.03869832e-04
#  2.54462794e-06]
#
# differential_evolution step 5: f(x)= 2.26843e+06
# parameters = [2.50000000e-01 1.83057128e-06 8.68780953e-02 2.54148199e-04
#  2.57373506e-06]
#
# differential_evolution step 6: f(x)= 2.26843e+06
# parameters = [2.50000000e-01 1.83057128e-06 8.68780953e-02 2.54148199e-04
#  2.57373506e-06]
#
# differential_evolution step 7: f(x)= 2.26843e+06
# parameters = [2.50000000e-01 1.83057128e-06 8.68780953e-02 2.54148199e-04
#  2.57373506e-06]
#
# differential_evolution step 8: f(x)= 2.26843e+06
# parameters = [2.50000000e-01 1.83057128e-06 8.68780953e-02 2.54148199e-04
#  2.57373506e-06]
#
# differential_evolution step 9: f(x)= 2.19716e+06
# parameters = [2.50000000e-01 1.90327790e-06 7.52164315e-02 2.42782207e-04
#  2.71314879e-06]
#
# differential_evolution step 10: f(x)= 2.19716e+06
# parameters = [2.50000000e-01 1.90327790e-06 7.52164315e-02 2.42782207e-04
#  2.71314879e-06]
#
# differential_evolution step 11: f(x)= 2.19716e+06
# parameters = [2.50000000e-01 1.90327790e-06 7.52164315e-02 2.42782207e-04
#  2.71314879e-06]
#
# differential_evolution step 12: f(x)= 1.94223e+06
# parameters = [2.50000000e-01 1.81096811e-06 8.17056862e-02 2.19421546e-04
#  2.41516967e-06]
#
# differential_evolution step 13: f(x)= 1.94223e+06
# parameters = [2.50000000e-01 1.81096811e-06 8.17056862e-02 2.19421546e-04
#  2.41516967e-06]
#
# differential_evolution step 14: f(x)= 1.93822e+06
# parameters = [2.50000000e-01 1.84841791e-06 8.24289086e-02 2.16472448e-04
#  2.41406874e-06]
#
# differential_evolution step 15: f(x)= 1.91493e+06
# parameters = [2.50000000e-01 1.74748905e-06 7.40507881e-02 1.97456275e-04
#  2.33012999e-06]
#
# differential_evolution step 16: f(x)= 1.90419e+06
# parameters = [2.50000000e-01 1.87129841e-06 8.13316075e-02 1.95609161e-04
#  2.30878093e-06]
#
# differential_evolution step 17: f(x)= 1.90419e+06
# parameters = [2.50000000e-01 1.87129841e-06 8.13316075e-02 1.95609161e-04
#  2.30878093e-06]
#
# differential_evolution step 18: f(x)= 1.8839e+06
# parameters = [2.50000000e-01 1.80219830e-06 7.80222778e-02 1.92909125e-04
#  2.28661587e-06]
#
# differential_evolution step 19: f(x)= 1.8839e+06
# parameters = [2.50000000e-01 1.80219830e-06 7.80222778e-02 1.92909125e-04
#  2.28661587e-06]
#
# differential_evolution step 20: f(x)= 1.88032e+06
# parameters = [2.50000000e-01 1.74261134e-06 7.68304040e-02 1.96505442e-04
#  2.28599363e-06]
#
# differential_evolution step 21: f(x)= 1.88032e+06
# parameters = [2.50000000e-01 1.74261134e-06 7.68304040e-02 1.96505442e-04
#  2.28599363e-06]
#
# differential_evolution step 22: f(x)= 1.88032e+06
# parameters = [2.50000000e-01 1.74261134e-06 7.68304040e-02 1.96505442e-04
#  2.28599363e-06]
#
# differential_evolution step 23: f(x)= 1.8787e+06
# parameters = [2.50000000e-01 1.69336901e-06 7.63195680e-02 1.99726555e-04
#  2.28006771e-06]
#
# differential_evolution step 24: f(x)= 1.87838e+06
# parameters = [2.50000000e-01 1.67693993e-06 7.57919268e-02 2.00960287e-04
#  2.28314714e-06]
#
# differential_evolution step 25: f(x)= 1.87838e+06
# parameters = [2.50000000e-01 1.67693993e-06 7.57919268e-02 2.00960287e-04
#  2.28314714e-06]
#
# differential_evolution step 26: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.68207758e-06 7.60748693e-02 2.01202356e-04
#  2.28476137e-06]
#
# differential_evolution step 27: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.68207758e-06 7.60748693e-02 2.01202356e-04
#  2.28476137e-06]
#
# differential_evolution step 28: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.68207758e-06 7.60748693e-02 2.01202356e-04
#  2.28476137e-06]
#
# differential_evolution step 29: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.66228520e-06 7.55995878e-02 1.99898900e-04
#  2.26883702e-06]
#
# differential_evolution step 30: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.66228520e-06 7.55995878e-02 1.99898900e-04
#  2.26883702e-06]
#
# differential_evolution step 31: f(x)= 1.87823e+06
# parameters = [2.50000000e-01 1.66228520e-06 7.55995878e-02 1.99898900e-04
#  2.26883702e-06]
#
# differential_evolution step 32: f(x)= 1.87817e+06
# parameters = [2.50000000e-01 1.67307094e-06 7.59189196e-02 2.00367851e-04
#  2.27520652e-06]
#
# differential_evolution step 33: f(x)= 1.87816e+06
# parameters = [2.50000000e-01 1.67012876e-06 7.57822992e-02 2.00264359e-04
#  2.27427742e-06]
#
# differential_evolution step 34: f(x)= 1.87813e+06
# parameters = [2.50000000e-01 1.66626132e-06 7.56794453e-02 2.00461149e-04
#  2.27413966e-06]
#
# differential_evolution step 35: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67057620e-06 7.57910265e-02 2.00763177e-04
#  2.27762264e-06]
#
# differential_evolution step 36: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67057620e-06 7.57910265e-02 2.00763177e-04
#  2.27762264e-06]
#
# differential_evolution step 37: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67057620e-06 7.57910265e-02 2.00763177e-04
#  2.27762264e-06]
#
# differential_evolution step 38: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67057620e-06 7.57910265e-02 2.00763177e-04
#  2.27762264e-06]
#
# differential_evolution step 39: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.67057620e-06 7.57910265e-02 2.00763177e-04
#  2.27762264e-06]
#
# differential_evolution step 40: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66876916e-06 7.57472924e-02 2.00653049e-04
#  2.27623645e-06]
#
# differential_evolution step 41: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66876916e-06 7.57472924e-02 2.00653049e-04
#  2.27623645e-06]
#
# differential_evolution step 42: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66876916e-06 7.57472924e-02 2.00653049e-04
#  2.27623645e-06]
#
# differential_evolution step 43: f(x)= 1.87812e+06
# parameters = [2.50000000e-01 1.66873452e-06 7.57472196e-02 2.00641164e-04
#  2.27613077e-06]
#
# ========================
# r1=0.25
# ef=1.668734524839995e-06
# m=0.07574721963310704
# a1=0.00020064116425065937
# a2=2.2761307691671906e-06
# ========================

# %% [markdown]
# * Retrieving the calibrated parameter values:

# %%
t0 = time_list.min()
tf = time_list.max()
days_to_forecast = 0
time_list_range = np.linspace(t0, tf + days_to_forecast, 100)
(
    r1_deterministic,
    ef_deterministic,
    m_deterministic,
    a1_deterministic,
    a2_deterministic,
) = result_M03.x

solution_ODE_M03 = M03_ode_solver(
    y0,
    (t0, tf + days_to_forecast), 
    time_list_range, 
    *result_M03.x
)
t_computed_M03, y_computed_M03 = solution_ODE_M03.t, solution_ODE_M03.y
u_M03, v_M03 = y_computed_M03

parameters_dict = {
    "Model": "M03",
    u"$r1$": r1_deterministic,
    u"$ef$": ef_deterministic,
    u"$m$": m_deterministic,
    u"$a1$": a1_deterministic,
    u"$a2$": a2_deterministic,
}

print("r1=" + str(r1_deterministic) + "\n" + "ef=" + str(ef_deterministic) + "\n" + "m=" + str(m_deterministic) + "\n" + "a1=" + str(a1_deterministic) + "\n" + "a2=" + str(a2_deterministic) )

df_parameters_calibrated = pd.DataFrame.from_records([parameters_dict])
# Out:
# r1=0.25
# ef=1.668734524839995e-06
# m=0.07574721963310704
# a1=0.00020064116425065937
# a2=2.2761307691671906e-06

# %% [markdown]
# #### Simulation

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 4))

aphid_observed = aphid_data[:].copy()
ladybeetle_observed = ladybeetle_data[:].copy()

plt.plot(t_computed_M03, u_M03, '-x')
plt.plot(time_list, aphid_density, 'o', label='Observed')

plt.xlabel('time')
plt.ylabel('Aphid Population')
plt.show()

plt.plot(t_computed_M03, v_M03, '-x')
plt.plot(time_list, ladybeetle_density, 'o', label='Observed')
plt.xlabel('time')
plt.ylabel('Ladybeetle Population')
plt.show()

# %% [markdown]
# ## Sensitivity Analyses

# %% [markdown]
# ### Least-Squares objective function

# %%
from SALib.sample.morris import sample as ee_sample

mean_values_params = [
    r1,
    ef,
    m,
    a1,
    a2,
]
factors_names = [
    r"$r1$",
    r"$ef$",
    r"$m$",
    r"$a1$",
    r"$a2$",
]
params_perturbations = 0.05
problem_info = {
    'num_vars': len(mean_values_params),
    'names': factors_names,
    'bounds': [[param - params_perturbations * param, param + params_perturbations * param] for param in mean_values_params]
}

grid_level = 4
num_of_trajectories = 20
parameter_values = ee_sample(problem_info, grid_level, num_of_trajectories, local_optimization=True, seed=seed)

# %%
from tqdm import tqdm

num_of_realizations = parameter_values.shape[0]
qoi_sensitivity_outputs = np.zeros(num_of_realizations)

for realization_index, parameters_realization in tqdm(enumerate(parameter_values), total=len(parameter_values)):
    
    residual_least_squares_result = M03_least_squares_error_ode(
        parameters_realization,
        time_list,
        [u_data, v_data],
        M03_ode_solver,
        y0
    )
    
    qoi_sensitivity_outputs[realization_index] = residual_least_squares_result
# Out:
# 100%|██████████████████████████████████████████| 24/24 [00:00<00:00, 161.37it/s]

# %%
from SALib.analyze.morris import analyze as ee_analyze

data_time_list = time_list
num_of_experimental_points = data_time_list.shape[0]

df_Si = pd.DataFrame(columns=[*problem_info['names']])

Si = ee_analyze(problem_info, parameter_values, qoi_sensitivity_outputs, num_levels=grid_level, seed=seed)
Si['mu_star_normalized'] = Si['mu_star'] / Si['mu_star'].sum()
for idx, param_name in enumerate(problem_info['names']):
    df_Si.loc[0, param_name] = Si['mu_star_normalized'][idx]

df_Si = df_Si.T
df_Si.rename(columns={0: r'$\mu^*$'}, inplace=True)
df_Si.sort_values(by=r'$\mu^*$', ascending=False, inplace=True)
df_Si
# Out:
#        $\mu^*$
# $a2$  0.347905
# $a1$  0.341261
# $m$   0.285525
# $ef$  0.015427
# $r1$  0.009881

# %%
df_Si.T.plot.bar(rot=0, width=3, figsize=(9, 6))

plt.rcParams.update({'font.size': 16})

plt.ylabel(r"$\mu^*$")

plt.legend(fancybox=True, shadow=True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Prey (pest) population

# %%
from SALib.sample.morris import sample as ee_sample

mean_values_params = [
    r1,
    ef,
    m,
    a1,
    a2,
]
factors_names = [
    r"$r1$",
    r"$ef$",
    r"$m$",
    r"$a1$",
    r"$a2$",
]
params_perturbations = 0.05
problem_info = {
    'num_vars': len(mean_values_params),
    'names': factors_names,
    'bounds': [[param - params_perturbations * param, param + params_perturbations * param] for param in mean_values_params]
}

grid_level = 4
num_of_trajectories = 20
parameter_values = ee_sample(problem_info, grid_level, num_of_trajectories, local_optimization=False, seed=seed)

# %%
from tqdm import tqdm

t0 = time_list.min()
tf = time_list.max()
days_to_forecast = 0
time_list_range = np.linspace(t0, tf + days_to_forecast, 100)

num_of_realizations = parameter_values.shape[0]
num_of_time_list_points = time_list_range.shape[0]
qoi_sensitivity_outputs = np.zeros([num_of_realizations, num_of_time_list_points])

for realization_index, parameters_realization in tqdm(enumerate(parameter_values), total=len(parameter_values)):
    
    realization_ODE_M03 = M03_ode_solver(
        y0, 
        (t0, tf + days_to_forecast), 
        time_list_range, 
        *parameters_realization
    )
    
    u_realization, v_realization = realization_ODE_M03.y
    
    qoi_sensitivity_outputs[realization_index, :] = u_realization
# Out:
# 100%|██████████████████████████████████████████| 24/24 [00:00<00:00, 168.41it/s]

# %%
from SALib.analyze.morris import analyze as ee_analyze

df_Si = pd.DataFrame(columns=['time_list', *problem_info['names']])
df_sigmai = pd.DataFrame(columns=['time_list', *problem_info['names']])
df_Si['time_list'] = time_list_range
df_sigmai['time_list'] = time_list_range
for time_list_point in tqdm(range(num_of_time_list_points)):
    Si = ee_analyze(
        problem_info, 
        parameter_values, 
        qoi_sensitivity_outputs[:, time_list_point], 
        num_levels=grid_level, 
        seed=seed
    )
    # Some parameters combinations may result in simulation failure.
    # This "if" skip such cases, since they do not have associated sensitivity indicies
    if np.isnan(Si["mu"][-1]):
        continue
        
    Si['mu_star_normalized'] = Si['mu_star'] / Si['mu_star'].sum()
    sigmai_normalized = Si['sigma'] / Si['sigma'].sum()
    for idx, param_name in enumerate(problem_info['names']):
        df_Si.loc[time_list_point, param_name] = Si['mu_star_normalized'][idx]
        df_sigmai.loc[time_list_point, param_name] = sigmai_normalized[idx]

df_Si.dropna(inplace=True)  # remove values that calculation was not possible
df_Si.sort_values(by='time_list', inplace=True)
df_Si.drop(index=0, inplace=True)
df_Si.dropna(inplace=True)
df_Si.reset_index(drop=True, inplace=True)

df_sigmai.sort_values(by='time_list', inplace=True)
df_sigmai.drop(index=0, inplace=True)
df_sigmai.dropna(inplace=True)
df_sigmai.reset_index(drop=True, inplace=True)

valid_time_lists = df_Si.time_list.values
df_Si
# Out:
# 100%|████████████████████████████████████████| 100/100 [00:00<00:00, 346.52it/s]
#     time_list      $r1$      $ef$       $m$      $a1$      $a2$
# 0    1.404040   0.42472   0.03385  0.016059  0.250712  0.274659
# 1    1.808081  0.382032  0.061532  0.030479  0.237109  0.288848
# 2    2.212121  0.347156  0.083807  0.043484  0.225611  0.299943
# 3    2.616162  0.319284  0.101662  0.054556  0.216377   0.30812
# 4    3.020202  0.296725  0.115517  0.064404  0.208838  0.314516
# ..        ...       ...       ...       ...       ...       ...
# 94  39.383838  0.071391  0.082215  0.227579  0.305499  0.313316
# 95  39.787879  0.071412   0.08202   0.22753  0.305459  0.313579
# 96  40.191919  0.071436  0.081826   0.22749   0.30542  0.313828
# 97  40.595960  0.071471  0.081644  0.227457  0.305362  0.314066
# 98  41.000000   0.07151  0.081467  0.227424  0.305289  0.314309
#
# [99 rows x 6 columns]

# %%
df_sigmai
# Out:
#     time_list      $r1$      $ef$       $m$      $a1$      $a2$
# 0    1.404040  0.025272  0.077886  0.023597   0.36186  0.511385
# 1    1.808081  0.042635  0.132663  0.044646  0.314835  0.465222
# 2    2.212121  0.057657  0.163238  0.059355  0.283758  0.435992
# 3    2.616162  0.068736  0.199742  0.079641  0.252741  0.399139
# 4    3.020202  0.081601  0.212696  0.093002  0.233287  0.379414
# ..        ...       ...       ...       ...       ...       ...
# 94  39.383838  0.071943  0.093924  0.184028  0.245592  0.404513
# 95  39.787879  0.071948  0.093757  0.183988  0.245537  0.404771
# 96  40.191919  0.071954  0.093589  0.183957  0.245486  0.405013
# 97  40.595960   0.07197  0.093432  0.183933  0.245426  0.405239
# 98  41.000000  0.071989   0.09328  0.183908  0.245355  0.405468
#
# [99 rows x 6 columns]

# %%
fig = plt.figure()
ax = plt.subplot(111)
step_to_plot = 12
valid_time_lists_to_plot_mu = valid_time_lists[::step_to_plot]
df_Si[::step_to_plot].plot.bar(x='time_list', rot=30, width=0.9, figsize=(40, 18), stacked=True, ax=ax)
ax.xaxis.set_major_formatter(lambda x, pos: f"{valid_time_lists_to_plot_mu[x]:.2f}")
#plt.xlabel("Time (days)", fontsize = 80), plt.ylabel(r"Normalized $\mu^*$", fontsize = 80), plt.xticks(fontsize=80), plt.yticks(fontsize=80)
plt.xlabel("", fontsize = 80), plt.ylabel("", fontsize = 80), plt.xticks(fontsize=80), plt.yticks(fontsize=80)

plt.ylim([0, 1])
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=len(problem_info['names']), fancybox=True, shadow=True, fontsize=90)

plt.tight_layout()
plt.savefig("img/SA_pest_pop_M03.png", format='png', bbox_inches = 'tight', dpi=50)
plt.show()

# %%
fig = plt.figure()
ax = plt.subplot(111)
step_to_plot = 12
valid_time_lists_to_plot_sigma = valid_time_lists[::step_to_plot]
df_sigmai[::step_to_plot].plot.bar(x='time_list', rot=30, width=0.9, figsize=(40, 18), stacked=True, ax=ax)
ax.xaxis.set_major_formatter(lambda x, pos: f"{valid_time_lists_to_plot_sigma[x]:.2f}")
#plt.xlabel("Time (days)", fontsize = 80), plt.ylabel(r"Normalized $\sigma$", fontsize = 80), plt.xticks(fontsize=80), plt.yticks(fontsize=80)
plt.xlabel("", fontsize = 80), plt.ylabel("", fontsize = 80), plt.xticks(fontsize=80), plt.yticks(fontsize=80)

plt.ylim([0, 1])
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=len(problem_info['names']), fancybox=True, shadow=True, fontsize=90)

plt.tight_layout()
plt.savefig("img/SA_pest_pop_sigma_M03.png", format='png', bbox_inches = 'tight', dpi=50)
plt.show()

# %% [markdown]
# ## Bayesian calibration

# %%
@theano.compile.ops.as_op(
    itypes=[
        t.dvector, 
        t.dscalar,  # r1 
        t.dscalar,  # ef
        t.dscalar,  # m
        t.dscalar,  # a1
        t.dscalar,  # a2
        t.dscalar,  # u0
        t.dscalar,  # v0
    ], 
    otypes=[t.dmatrix]
)
def M03_ode_wrapper(time_list_exp, r1, ef, m, a1, a2, u0, v0):
    time_list_span = (time_list_exp.min(), time_list_exp.max())

    args = [r1, ef, m, a1, a2]
    initial_conditions = np.array([u0, v0])
    y_model = solve_ivp(
        M03_model, 
        time_list_span, 
        initial_conditions, 
        t_eval=time_list_exp, 
        method='Radau',
        args=args
    )
    simulated_time_list = y_model.t
    simulated_ode_solution = y_model.y
    simulated_qoi1, simulated_qoi2 = simulated_ode_solution

    concatenate_simulated_qoi = np.vstack([simulated_qoi1, simulated_qoi2]).T

    return concatenate_simulated_qoi

# %%
observed_aphids = aphid_density.astype(np.float64)
observed_ladybeetles = ladybeetle_density.astype(np.float64)
observations_to_fit = np.vstack([observed_aphids, observed_ladybeetles]).T  # note the transpose here
time_observations = time_list.astype(np.float64)

print("\n*** Performing Bayesian calibration ***")

print("-- Running Monte Carlo simulations:")
start_time = time.time()
denom_min = 0.95
denom_max = 1.05

with pm.Model() as fine_model_M03:
    # Prior distributions for the model's parameters
    r1_ = pm.Data("r1", r1)
    ef_ = pm.Data("ef", ef)
    m_ = pm.Uniform(
        "m",
        lower=0.085,
        upper=0.115,
   )
    a1_ = pm.Uniform(
        "a1",
        lower=0.00026,
        upper=0.00033,
   )
    a2_ = pm.Uniform(
        "a2",
        lower=2.22e-6,
        upper=2.867e-6,
   )

    # Prioris for Initial Conditions
    u0, v0 = y0
    u0_ = pm.Data("u0", u0)
    v0_ = pm.Data("v0", v0)

    standard_deviation = pm.Uniform("std_deviation", lower=0, upper=1000, shape=2)  # note 'shape' here

    # Wrapper for time_list. We need it this way in order to change it for predictions
    time_calibration = pm.Data("time", time_observations)

    # Defining the deterministic formulation of the problem
    fitting_model = pm.Deterministic(
        "M03_model",
        M03_ode_wrapper(
            time_calibration,
            r1_,
            ef_,
            m_,
            a1_,
            a2_,
            u0_,
            v0_
        ),
    )
    
    likelihood_model = pm.Normal(
        "likelihood_model", mu=fitting_model, sigma=standard_deviation, observed=observations_to_fit
    )
    
coarse_steps_1 = 4
observed_aphids_coarse_1 = observed_aphids[::coarse_steps_1]
observed_ladybeetles_coarse_1 = observed_ladybeetles[::coarse_steps_1]
observations_to_fit_coarse_1 = np.vstack(
    [observed_aphids_coarse_1, observed_ladybeetles_coarse_1]
).T
time_observations_coarse_1 = time_observations[::coarse_steps_1]

with pm.Model() as coarse_model_1:
    # Prior distributions for the model's parameters
    r1_ = pm.Data("r1", r1)
    ef_ = pm.Data("ef", ef)
    m_ = pm.Uniform(
        "m",
        lower=0.085,
        upper=0.115,
   )
    a1_ = pm.Uniform(
        "a1",
        lower=0.00026,
        upper=0.00033,
   )
    a2_ = pm.Uniform(
        "a2",
        lower=2.22e-6,
        upper=2.867e-6,
   )
    
    # Prioris for Initial Conditions
    u0, v0 = y0
    u0_ = pm.Data("u0", u0)
    v0_ = pm.Data("v0", v0)

    standard_deviation = pm.Uniform("std_deviation", lower=0, upper=1000, shape=2)  # note 'shape' here

    # Wrapper for time_list. We need it this way in order to change it for predictions
    time_calibration = pm.Data("time", time_observations_coarse_1)

    # Defining the deterministic formulation of the problem
    fitting_model = pm.Deterministic(
        "M03_model",
        M03_ode_wrapper(
            time_calibration,
            r1_,
            ef_,
            m_,
            a1_,
            a2_,
            u0_,
            v0_
        ),
    )
    
    likelihood_model = pm.Normal(
        "likelihood_model", mu=fitting_model, sigma=standard_deviation, observed=observations_to_fit_coarse_1
    )


with fine_model_M03:
    step = pm.MLDA(coarse_models=[coarse_model_1], subsampling_rates=[5])
    trace_calibration_M03 = pm.sample(draws=6000, chains=6, cores=6, tune=2000, step=step, random_seed=seed)

duration = time.time() - start_time

print(f"-- Monte Carlo simulations done in {duration / 60:.3f} minutes")
# Out:
# *** Performing Bayesian calibration ***
# -- Running Monte Carlo simulations:
# Multiprocess sampling (6 chains in 6 jobs)
# MLDA: [std_deviation, a2, a1, m]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='48000' class='' max='48000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [48000/48000 20:52&lt;00:00 Sampling 6 chains, 0 divergences]
#     </div>
# Sampling 6 chains for 2_000 tune and 6_000 draw iterations (12_000 + 36_000 draws total) took 1253 seconds.
# The rhat statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
# -- Monte Carlo simulations done in 23.780 minutes

# %% [markdown]
# plt.hist(trace_calibration_M03['m'], bins=35)
# plt.show()
# plt.hist(trace_calibration_M03['a1'], bins=35)
# plt.show()
# plt.hist(trace_calibration_M03['a2'], bins=35)
# plt.show()

# %%
calibration_variable_names = [
    "std_deviation",
    "m",
    "a1",
    "a2",
]

plot_step = 1
progress_bar = tqdm(calibration_variable_names)
for variable in progress_bar:
    if calibration_variable_names==a1:
        ax = plt.gca()
        x = np.arange(0.00026, 0.00033, 0.00005, dtype = float)
        ax.set_xticks(x, minor=True)
    pm.plot_posterior(
        trace_calibration_M03[::plot_step], 
        var_names=(f"{variable}"), 
        kind="hist",
        bins=35,
        round_to=None,
        textsize=18,
        point_estimate="mode"
    )
    plt.savefig(f"img/posterior_cal_M03_{variable}.png", bbox_inches='tight', pad_inches=0)
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]Got error No model on context stack. trying to find log_likelihood in translation.
#  25%|███████████                                 | 1/4 [02:48<08:26, 168.94s/it]Got error No model on context stack. trying to find log_likelihood in translation.
#  50%|██████████████████████                      | 2/4 [05:45<05:46, 173.42s/it]Got error No model on context stack. trying to find log_likelihood in translation.
#  75%|█████████████████████████████████           | 3/4 [08:46<02:56, 176.71s/it]Got error No model on context stack. trying to find log_likelihood in translation.
# 100%|████████████████████████████████████████████| 4/4 [11:33<00:00, 173.31s/it]

# %%
calibration_variable_names = [
    "std_deviation",
    "m",
    "a1",
    "a2",
]

plot_step = 1
progress_bar = tqdm(calibration_variable_names)
for variable in progress_bar:
    if calibration_variable_names==a1:
        ax = plt.gca()
        x = np.arange(0.00026, 0.00033, 0.00005, dtype = float)
        ax.set_xticks(x, minor=True)
    pm.plot_posterior(
        trace_calibration_M03[::plot_step], 
        var_names=(f"{variable}"), 
        kind="kde",
        bins=35,
        round_to=None,
        textsize=18,
        point_estimate="mode"
    )
#    plt.savefig(f"img/posterior_cal_M03_KDE_{variable}.png", bbox_inches='tight', pad_inches=0)
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]Got error No model on context stack. trying to find log_likelihood in translation.
#  25%|███████████                                 | 1/4 [02:38<07:56, 158.69s/it]Got error No model on context stack. trying to find log_likelihood in translation.
#  50%|██████████████████████                      | 2/4 [05:17<05:17, 158.91s/it]Got error No model on context stack. trying to find log_likelihood in translation.
#  75%|█████████████████████████████████           | 3/4 [07:56<02:38, 158.83s/it]Got error No model on context stack. trying to find log_likelihood in translation.
# 100%|████████████████████████████████████████████| 4/4 [10:34<00:00, 158.73s/it]

# %%
az.plot_pair(
    trace_calibration_M03,
    var_names=calibration_variable_names,
    kind="hexbin",
    fill_last=False,
    marginals=True,
    figsize=(10, 8),
)
plt.savefig("img/marginals_cal_M03.png")
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
df_stats_summary = az.summary(
    data=trace_calibration_M03,
    var_names=calibration_variable_names,
    kind='stats',
    round_to=15,  # rounding level display
)

df_stats_summary
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
#                         mean            sd      hdi_3%     hdi_97%
# std_deviation[0]  192.256412  1.363646e+01  168.042670  218.816256
# std_deviation[1]    1.493063  1.064300e-01    1.296222    1.683413
# m                   0.103335  5.383843e-03    0.095355    0.114999
# a1                  0.000299  1.237075e-05    0.000277    0.000324
# a2                  0.000003  9.190565e-08    0.000002    0.000003

# %% [markdown]
# Auxiliary functions to compute the Most Probable Value (MPV):

# %%
from scipy.stats import gaussian_kde  # to calculate MPV from KDE

def _scalar_rv_mvp_estimation(rv_realization_values: np.ndarray) -> np.ndarray:
    num_of_realizations = len(rv_realization_values)
    kernel = gaussian_kde(rv_realization_values)
    equally_spaced_samples = np.linspace(
        rv_realization_values.min(),
        rv_realization_values.max(),
        num_of_realizations
    )
    kde = kernel(equally_spaced_samples)
    kde_max_index = np.argmax(kde)
    rv_mpv_value = equally_spaced_samples[kde_max_index]
    return rv_mpv_value


def calculate_rv_posterior_mpv(pm_trace, variable_names: list) -> dict:
    rv_mpv_values_dict = dict()
    progress_bar = tqdm(variable_names)
    for variable in progress_bar:
        progress_bar.set_description(f"Calculating MPV from KDE for {variable}")
        rv_realization_values = pm_trace[f"{variable}"]

        try:
            num_of_dimensions = rv_realization_values.shape[1]
        except IndexError:
            num_of_dimensions = 0

        if num_of_dimensions == 0:
            rv_mpv_value = _scalar_rv_mvp_estimation(rv_realization_values)
            rv_mpv_values_dict[f"{variable}"] = rv_mpv_value
        else:
            for dimension in range(num_of_dimensions):
                variable_name_decomposed = f"{variable}[{dimension}]"
                rv_realization_values_decomposed = np.array(rv_realization_values[:, dimension])
                rv_mpv_value = _scalar_rv_mvp_estimation(rv_realization_values_decomposed)
                rv_mpv_values_dict[f"{variable_name_decomposed}"] = rv_mpv_value

    return rv_mpv_values_dict


def add_mpv_to_summary(arviz_summary: pd.DataFrame, rv_modes_dict: dict) -> pd.DataFrame:
    new_arviz_summary = arviz_summary.copy()
    variable_names = list(rv_modes_dict.keys())
    rv_mode_values = list(rv_modes_dict.values())
    new_arviz_summary["mpv"] = pd.Series(data=rv_mode_values, index=variable_names)
    return new_arviz_summary

# %%
calibration_variable_mpv = calculate_rv_posterior_mpv(
    pm_trace=trace_calibration_M03, variable_names=calibration_variable_names
)
df_stats_summary = add_mpv_to_summary(df_stats_summary, calibration_variable_mpv)
df_stats_summary.to_csv("csv/stats_summary_calibration_M03.csv")  # save in csv format

df_stats_summary
# Out:
# Calculating MPV from KDE for a2: 100%|████████████| 4/4 [00:44<00:00, 11.19s/it]
#                         mean            sd      hdi_3%     hdi_97%         mpv
# std_deviation[0]  192.256412  1.363646e+01  168.042670  218.816256  190.814686
# std_deviation[1]    1.493063  1.064300e-01    1.296222    1.683413    1.473788
# m                   0.103335  5.383843e-03    0.095355    0.114999    0.102103
# a1                  0.000299  1.237075e-05    0.000277    0.000324    0.000297
# a2                  0.000003  9.190565e-08    0.000002    0.000003    0.000003

# %%
percentile_cut = 2.5

y_min = np.percentile(trace_calibration_M03["M03_model"], percentile_cut, axis=0)
y_max = np.percentile(trace_calibration_M03["M03_model"], 100 - percentile_cut, axis=0)
y_fit = np.percentile(trace_calibration_M03["M03_model"], 50, axis=0)

# %%
plt.figure(figsize=(15, 7.5))

plt.plot(
    time_observations,
    y_fit[:, 0],
    "firebrick",
    label="Aphids (simulated)",
    marker="X",
    linestyle="-",
    markersize=5,
)
plt.fill_between(time_observations, y_min[:, 0], y_max[:, 0], color="firebrick", alpha=0.2)

plt.plot(
    time_observations,
    y_fit[:, 1],
    "darkblue",
    label="Ladybeetles (simulated)",
    marker="o",
    linestyle="-",
    markersize=5,
)
plt.fill_between(time_observations, y_min[:, 1], y_max[:, 1], color="darkblue", alpha=0.2)

plt.plot(
    time_observations, 
    aphid_density, 
    label="Aphids data", 
    marker="s", 
    linestyle="", 
    markersize=5
)
plt.plot(
    time_observations, 
    ladybeetle_density, 
    label="Ladybeetles data", 
    marker="v", 
    linestyle="", 
    markersize=5
)

plt.legend(shadow=True)
plt.xlabel('Time (days)', fontsize=15)
plt.ylabel('Population densities', fontsize=15)

plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15, 7.5), dpi = 300)
ax2 = ax1.twinx()
ax1.plot(time_observations, aphid_density, "bo", alpha = 0.5, markersize = 8)
ax2.plot(time_observations, ladybeetle_density, "r^", alpha = 0.5, markersize = 8)
ax1.plot(time_observations, y_fit[:, 0], "darkblue", alpha = 1.0, linewidth = 4)
ax2.plot(time_observations, y_fit[:, 1], "firebrick", alpha = 1.0, linewidth = 4)

ax1.fill_between(time_observations, y_min[:,0], y_max[:,0], color = "darkblue", alpha = 0.4)
ax2.fill_between(time_observations, y_min[:,1], y_max[:,1], color = "firebrick", alpha = 0.4)
#ax1.set_xlabel(r"Time (days)", fontsize=40)
#ax1.set_ylabel(r"Aphid", color = "darkblue", fontsize=40)
#ax2.set_ylabel(r"Ladybeetle", color = "firebrick", fontsize=40)
ax1.tick_params(axis = "y", labelcolor = "darkblue")
ax2.tick_params(axis = "y", labelcolor = "firebrick")
ax1.ticklabel_format(useOffset=False)
ax2.ticklabel_format(useOffset=False)

ax2.set_ylim([2, 7.5])

ax1.tick_params(labelsize=40)
ax2.tick_params(labelsize=40)

plt.tight_layout()
plt.savefig("img/calibration_M03.png", dpi=300)
plt.show()

# %%
print("-- Exporting calibrated parameter to CSV")

start_time = time.time()

dict_realizations = dict()  # save the realizations in a Python dictionary
progress_bar = tqdm(calibration_variable_names[1:])
for variable in progress_bar:
    progress_bar.set_description(f"Gathering {variable} realizations")
    parameter_realization = trace_calibration_M03.get_values(f"{variable}")
    dict_realizations[f"{variable}"] = parameter_realization

df_realizations = pd.DataFrame(dict_realizations)
df_realizations.to_csv("csv/calibration_realizations_M03.csv")

duration = time.time() - start_time

print(f"-- Exported done in {duration:.3f} seconds")
# Out:
# -- Exporting calibrated parameter to CSV
# Gathering a2 realizations: 100%|████████████████| 3/3 [00:00<00:00, 1978.76it/s]
# -- Exported done in 0.099 seconds

# %%
df_realizations
# Out:
#               m        a1        a2
# 0      0.102956  0.000296  0.000002
# 1      0.102956  0.000296  0.000002
# 2      0.106006  0.000307  0.000003
# 3      0.108579  0.000298  0.000002
# 4      0.108579  0.000298  0.000002
# ...         ...       ...       ...
# 35995  0.104470  0.000297  0.000002
# 35996  0.104806  0.000297  0.000002
# 35997  0.104165  0.000295  0.000002
# 35998  0.106690  0.000302  0.000002
# 35999  0.106690  0.000302  0.000002
#
# [36000 rows x 3 columns]
